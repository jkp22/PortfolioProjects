# %% [markdown]
# # Objective:
# #### In this project my goal is to predict the 2023 best picture award for The Oscars
# #### I will mainly doing so by how other nominations play a part in the prediction
# ##### *However I added some other factors in this project in order to practice my eda skills

# %% [markdown]
# ## Note:
# ### I gathered this data through https://m.imdb.com/list/ls076133705/ using webscrapper
# ### As this list has not been updated I repeatedly did the same process on other years. Sticking to imbd as my website of choice

# %%
# Loading Packages
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # Exploring the data

# %%
oscars = pd.read_csv(r"C:\Users\kylep\Documents\Work things\Projects\Python\Oscars\EveryBestPicNom_Final_v2.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
oscars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3759 entries, 0 to 3758
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movie_number        3759 non-null   int64
#  1   Movie               298 non-null    object
#  2   Title               3759 non-null   object
#  3   Date                3759 non-null   int64
#  4   Viewership_Rating   3746 non-null   object
#  5   Runtime             3746 non-null   object
#  6   IMDb Rating         3754 non-null   float64
#  7   Country of Origin   3759 non-null   object
#  8   Production Company  3759 non-null   object
#  9   Budget              3198 non-null   object
#  10  nominations         3759 non-null   object
#  11  Genre 1             3759 non-null   object
#  12  Genre 2             3384 non-null   object
#  13  Genre 3             2347 non-null   object
#  14  Gross Worldwide     2767 non-null   float64
# dtypes: float64(2), int64(2), object(11)
# memory usage: 440.6+ KB

# %%
oscars.head()
# Out:
#    movie_number Movie       Title  Date Viewership_Rating Runtime  \
# 0             1   NaN       Wings  1927             PG-13  2h 24m
# 1             1   NaN       Wings  1927             PG-13  2h 24m
# 2             2   NaN  7th Heaven  1927               NaN     NaN
# 3             2   NaN  7th Heaven  1927               NaN     NaN
# 4             2   NaN  7th Heaven  1927               NaN     NaN
#
#    IMDb Rating Country of Origin                  Production Company  \
# 0          7.6     United States  Paramount Famous Lasky Corporation
# 1          7.6     United States  Paramount Famous Lasky Corporation
# 2          7.6     United States            Frank Borzage Production
# 3          7.6     United States            Frank Borzage Production
# 4          7.6     United States            Frank Borzage Production
#
#                    Budget                        nominations Genre 1  Genre 2  \
# 0  $2,000,000 (estimated)           Best Picture, Production   Drama  Romance
# 1  $2,000,000 (estimated)  Best Effects, Engineering Effects   Drama  Romance
# 2  $1,300,000 (estimated)           Best Picture, Production   Drama  Romance
# 3  $1,300,000 (estimated)     Best Actress in a Leading Role   Drama  Romance
# 4  $1,300,000 (estimated)    Best Director, Dramatic Picture   Drama  Romance
#
#   Genre 3  Gross Worldwide
# 0     War            746.0
# 1     War            746.0
# 2     NaN              NaN
# 3     NaN              NaN
# 4     NaN              NaN

# %%
oscars.tail()
# Out:
#       movie_number          Movie          Title  Date Viewership_Rating  \
# 3754           590            Tár            Tár  2022                 R
# 3755           590            Tár            Tár  2022                 R
# 3756           590            Tár            Tár  2022                 R
# 3757           591  Women Talking  Women Talking  2022             PG-13
# 3758           591  Women Talking  Women Talking  2022             PG-13
#
#      Runtime  IMDb Rating Country of Origin  \
# 3754  2h 38m          7.5     United States
# 3755  2h 38m          7.5     United States
# 3756  2h 38m          7.5     United States
# 3757  1h 44m          6.9     United States
# 3758  1h 44m          6.9     United States
#
#                                      Production Company  \
# 3754  Focus FeaturesStandard Film CompanyEMJAG Produ...
# 3755  Focus FeaturesStandard Film CompanyEMJAG Produ...
# 3756  Focus FeaturesStandard Film CompanyEMJAG Produ...
# 3757           Hear/Say ProductionsPlan B Entertainment
# 3758           Hear/Say ProductionsPlan B Entertainment
#
#                        Budget                         nominations Genre 1  \
# 3754  $25,000,000 (estimated)            Best Original Screenplay   Drama
# 3755  $25,000,000 (estimated)  Best Achievement in Cinematography   Drama
# 3756  $25,000,000 (estimated)    Best Achievement in Film Editing   Drama
# 3757                      NaN             Best Adapted Screenplay   Drama
# 3758                      NaN     Best Motion Picture of the Year   Drama
#
#      Genre 2 Genre 3  Gross Worldwide
# 3754   Music     NaN       28350185.0
# 3755   Music     NaN       28350185.0
# 3756   Music     NaN       28350185.0
# 3757     NaN     NaN        8959129.0
# 3758     NaN     NaN        8959129.0

# %%
oscars.isnull().sum()
# Out:
# movie_number             0
# Movie                 3461
# Title                    0
# Date                     0
# Viewership_Rating       13
# Runtime                 13
# IMDb Rating              5
# Country of Origin        0
# Production Company       0
# Budget                 561
# nominations              0
# Genre 1                  0
# Genre 2                375
# Genre 3               1412
# Gross Worldwide        992
# dtype: int64

# %%
oscars.dtypes
# Out:
# movie_number            int64
# Movie                  object
# Title                  object
# Date                    int64
# Viewership_Rating      object
# Runtime                object
# IMDb Rating           float64
# Country of Origin      object
# Production Company     object
# Budget                 object
# nominations            object
# Genre 1                object
# Genre 2                object
# Genre 3                object
# Gross Worldwide       float64
# dtype: object

# %% [markdown]
# ### As we can see there are alot  things I need to work on before I can begin to use machine learning techniques
# #### The two major problems are:
#  - There are many nulls, in various columns
#  - Some data types are not well sutied for that column
#  - There are many duplicates

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# ### Fixing the movie and title columns

# %%
oscars[['Title','Movie']].head() # From what we can see here the Title column
# Out:
#         Title Movie
# 0       Wings   NaN
# 1       Wings   NaN
# 2  7th Heaven   NaN
# 3  7th Heaven   NaN
# 4  7th Heaven   NaN

# %%
oscars['Title'].isnull().sum() #Checking if there are any nulls
# Out:
# 0

# %%
oscars = oscars.drop('Movie', axis=1) #We dont need two title columns.Dropping the movie column

# %%
oscars.head()
# Out:
#    movie_number       Title  Date Viewership_Rating Runtime  IMDb Rating  \
# 0             1       Wings  1927             PG-13  2h 24m          7.6
# 1             1       Wings  1927             PG-13  2h 24m          7.6
# 2             2  7th Heaven  1927               NaN     NaN          7.6
# 3             2  7th Heaven  1927               NaN     NaN          7.6
# 4             2  7th Heaven  1927               NaN     NaN          7.6
#
#   Country of Origin                  Production Company  \
# 0     United States  Paramount Famous Lasky Corporation
# 1     United States  Paramount Famous Lasky Corporation
# 2     United States            Frank Borzage Production
# 3     United States            Frank Borzage Production
# 4     United States            Frank Borzage Production
#
#                    Budget                        nominations Genre 1  Genre 2  \
# 0  $2,000,000 (estimated)           Best Picture, Production   Drama  Romance
# 1  $2,000,000 (estimated)  Best Effects, Engineering Effects   Drama  Romance
# 2  $1,300,000 (estimated)           Best Picture, Production   Drama  Romance
# 3  $1,300,000 (estimated)     Best Actress in a Leading Role   Drama  Romance
# 4  $1,300,000 (estimated)    Best Director, Dramatic Picture   Drama  Romance
#
#   Genre 3  Gross Worldwide
# 0     War            746.0
# 1     War            746.0
# 2     NaN              NaN
# 3     NaN              NaN
# 4     NaN              NaN

# %% [markdown]
# ### Fixing Viwership Rating

# %%
oscars['Viewership_Rating'].isnull().sum()
# Out:
# 13

# %%
oscars['Viewership_Rating'].value_counts() #Making every naan into not rated category
# Out:
# R            1140
# PG-13         600
# PG            522
# Passed        510
# Approved      408
# Not Rated     253
# G             202
# Unrated        69
# M/PG           17
# X              10
# GP              6
# TV-MA           5
# TV-PG           4
# Name: Viewership_Rating, dtype: int64

# %%
oscars.Viewership_Rating = oscars.Viewership_Rating.fillna('Not Rated')

# %%
oscars['Viewership_Rating'].value_counts()#Checking if the not rated increased
# Out:
# R            1140
# PG-13         600
# PG            522
# Passed        510
# Approved      408
# Not Rated     266
# G             202
# Unrated        69
# M/PG           17
# X              10
# GP              6
# TV-MA           5
# TV-PG           4
# Name: Viewership_Rating, dtype: int64

# %%
oscars['Viewership_Rating'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Fixing Runtime by average

# %%
oscars['Runtime'].isnull().sum()
# Out:
# 13

# %%
oscars['Runtime'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### The problem in this column is the values are not easily readable for the computer. What I wish to happen is to replace all nulls with average runtime. However in order to do so the compter need interger datatypes. So converting the the column will be the first step.

# %%
oscars.Runtime = oscars.Runtime.fillna('0h') # This allows the next cell to run without any errors

# %%
h = oscars['Runtime'].str.extract('(\d+)h', expand=False).astype(float) * 60 #extracting all strings before h and multiplying them by 60
m = oscars['Runtime'].str.extract('(\d+)m', expand=False).astype(float) #extracting all strings before m

oscars['Duration'] = h.add(m, fill_value=0).astype(int) #creating a new column by adding h and m variables and turing them into int data types

# %%
x = oscars.Duration[oscars.Duration != 0].mean() #Creating a variable x that gives the average duration for a movie
print("The average duration of a movie is, " + str(round(x, 2)) + " in minutes")
# Out:
# The average duration of a movie is, 130.76 in minutes

# %%
oscars.head()
# Out:
#    movie_number       Title  Date Viewership_Rating Runtime  IMDb Rating  \
# 0             1       Wings  1927             PG-13  2h 24m          7.6
# 1             1       Wings  1927             PG-13  2h 24m          7.6
# 2             2  7th Heaven  1927         Not Rated      0h          7.6
# 3             2  7th Heaven  1927         Not Rated      0h          7.6
# 4             2  7th Heaven  1927         Not Rated      0h          7.6
#
#   Country of Origin                  Production Company  \
# 0     United States  Paramount Famous Lasky Corporation
# 1     United States  Paramount Famous Lasky Corporation
# 2     United States            Frank Borzage Production
# 3     United States            Frank Borzage Production
# 4     United States            Frank Borzage Production
#
#                    Budget                        nominations Genre 1  Genre 2  \
# 0  $2,000,000 (estimated)           Best Picture, Production   Drama  Romance
# 1  $2,000,000 (estimated)  Best Effects, Engineering Effects   Drama  Romance
# 2  $1,300,000 (estimated)           Best Picture, Production   Drama  Romance
# 3  $1,300,000 (estimated)     Best Actress in a Leading Role   Drama  Romance
# 4  $1,300,000 (estimated)    Best Director, Dramatic Picture   Drama  Romance
#
#   Genre 3  Gross Worldwide  Duration
# 0     War            746.0       144
# 1     War            746.0       144
# 2     NaN              NaN         0
# 3     NaN              NaN         0
# 4     NaN              NaN         0

# %%
oscars.loc[oscars["Duration"] == 0,"Duration"] = round(x, 2) #Filtering the data by 0 duration(which was previously nulls values)
                                                            #Then filling it the average duration(variable x)

# %%
oscars[['Runtime','Duration']].head(10)
# Out:
#   Runtime  Duration
# 0  2h 24m    144.00
# 1  2h 24m    144.00
# 2      0h    130.76
# 3      0h    130.76
# 4      0h    130.76
# 5      0h    130.76
# 6      0h    130.76
# 7  1h 24m     84.00
# 8  1h 40m    100.00
# 9  1h 40m    100.00

# %%
oscars = oscars.drop('Runtime', axis=1) # no longer need the runtime column

# %% [markdown]
# ## Fixing IMDb rating column

# %%
oscars['IMDb Rating'].isnull().sum()
# Out:
# 5

# %%
y = oscars[oscars["IMDb Rating"] != 0]["IMDb Rating"].mean()
print("The average IMDb rating for a best picture nominee is: " + str(round(y,2)))
# Out:
# The average IMDb rating for a best picture nominee is: 7.62

# %%
oscars['IMDb Rating'] = oscars['IMDb Rating'].fillna(round(y,2)) # Filling the nulls with average

# %% [markdown]
# ## Checking Country of Origin

# %%
oscars['Country of Origin'].isnull().sum()
# Out:
# 0

# %%
oscars['Country of Origin'].value_counts()
# Out:
# United States     2988
# United Kingdom     467
# Australia           52
# New Zealand         47
# Italy               36
# France              31
# Germany             28
# Ireland             25
# Hong Kong           12
# Mexico              10
# Taiwan              10
# Sweden              10
# China                9
# Greece               7
# South Korea          6
# Austria              5
# Brazil               4
# South Africa         4
# Spain                4
# Japan                4
# Name: Country of Origin, dtype: int64

# %% [markdown]
# ## Checking Production company

# %%
oscars['Production Company'].value_counts().head() #Note: I am doing .head() so when the notebook is published less space is taken.
# Out:
# Warner Bros.                 305
# Paramount Pictures           280
# Twentieth Century Fox        252
# Columbia Pictures            240
# Metro-Goldwyn-Mayer (MGM)    238
# Name: Production Company, dtype: int64

# %%
oscars['Production Company'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Checking Budget

# %%
oscars['Budget'].head(10)
# Out:
# 0    $2,000,000 (estimated)
# 1    $2,000,000 (estimated)
# 2    $1,300,000 (estimated)
# 3    $1,300,000 (estimated)
# 4    $1,300,000 (estimated)
# 5    $1,300,000 (estimated)
# 6    $1,300,000 (estimated)
# 7                       NaN
# 8      $379,000 (estimated)
# 9      $379,000 (estimated)
# Name: Budget, dtype: object

# %%
oscars['Budget'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# #### There are some problems in this column:
# - It should be assumed that these values are estimated and thus must remove any mention of it
# - There are null values here
# - There are different currencies here

# %%
oscars['Budget'] = oscars['Budget'].str.replace(r'[(estimated)]','')
# Out:
# C:\Users\kylep\AppData\Local\Temp\ipykernel_22292\1568365881.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   oscars['Budget'] = oscars['Budget'].str.replace(r'[(estimated)]','')

# %%
oscars['Budget'].head() #Checking to see if it removed unwanted strings
# Out:
# 0    $2,000,000
# 1    $2,000,000
# 2    $1,300,000
# 3    $1,300,000
# 4    $1,300,000
# Name: Budget, dtype: object

# %%
import reprlib #Note: only done to save space in publish. During actual eda, remove replib
print(reprlib.repr(oscars['Budget'].unique().tolist()))
 #Finding some other currencies
# Out:
# ['$2,000,000 ', '$1,300,000 ', nan, '$379,000 ', '$1,000,000 ', '$1,200,000 ', ...]

# %%
fil_cur = oscars[(oscars['Budget'].notna()) & (oscars['Country of Origin'] != 'United States' )]
fil_cur[['Budget','Country of Origin']].head()  #I wanted to see the various types of currency
# Out:
#        Budget Country of Origin
# 101  £60,000     United Kingdom
# 102  £60,000     United Kingdom
# 334  £87,000     United Kingdom
# 335  £87,000     United Kingdom
# 336  £87,000     United Kingdom

# %%
oscars['Currency'] = oscars['Budget'].astype(str).str[0]
#Since all currency types are shown at the start of the object I will create its own column

# %%
oscars['Currency'].value_counts() #all types of currency plus nulls(n)
# Out:
# $    3118
# n     561
# £      73
# €       7
# Name: Currency, dtype: int64

# %%
oscars.head()
# Out:
#    movie_number       Title  Date Viewership_Rating  IMDb Rating  \
# 0             1       Wings  1927             PG-13          7.6
# 1             1       Wings  1927             PG-13          7.6
# 2             2  7th Heaven  1927         Not Rated          7.6
# 3             2  7th Heaven  1927         Not Rated          7.6
# 4             2  7th Heaven  1927         Not Rated          7.6
#
#   Country of Origin                  Production Company       Budget  \
# 0     United States  Paramount Famous Lasky Corporation  $2,000,000
# 1     United States  Paramount Famous Lasky Corporation  $2,000,000
# 2     United States            Frank Borzage Production  $1,300,000
# 3     United States            Frank Borzage Production  $1,300,000
# 4     United States            Frank Borzage Production  $1,300,000
#
#                          nominations Genre 1  Genre 2 Genre 3  \
# 0           Best Picture, Production   Drama  Romance     War
# 1  Best Effects, Engineering Effects   Drama  Romance     War
# 2           Best Picture, Production   Drama  Romance     NaN
# 3     Best Actress in a Leading Role   Drama  Romance     NaN
# 4    Best Director, Dramatic Picture   Drama  Romance     NaN
#
#    Gross Worldwide  Duration Currency
# 0            746.0    144.00        $
# 1            746.0    144.00        $
# 2              NaN    130.76        $
# 3              NaN    130.76        $
# 4              NaN    130.76        $

# %%
oscars['Budget'] = oscars['Budget'].str.replace(',', '') #Replacing ,
oscars['Budget'] = oscars['Budget'].str.replace('$', '') #Replacing $
oscars['Budget'] = oscars['Budget'].str.replace('£', '') #£
oscars['Budget'] = oscars['Budget'].str.replace('€', '') #€
#Replacing unwanted strings so that I could later convert them into $
# Out:
# C:\Users\kylep\AppData\Local\Temp\ipykernel_22292\2894124609.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   oscars['Budget'] = oscars['Budget'].str.replace('$', '') #Replacing $

# %%
oscars.Budget = oscars.Budget.fillna(0) #Filling naan with 0 so its easier to convert data types

# %%
oscars['Budget'] = oscars['Budget'].astype(int)

# %%
oscars.info() # Checking if Budget is a int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3759 entries, 0 to 3758
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movie_number        3759 non-null   int64
#  1   Title               3759 non-null   object
#  2   Date                3759 non-null   int64
#  3   Viewership_Rating   3759 non-null   object
#  4   IMDb Rating         3759 non-null   float64
#  5   Country of Origin   3759 non-null   object
#  6   Production Company  3759 non-null   object
#  7   Budget              3759 non-null   int32
#  8   nominations         3759 non-null   object
#  9   Genre 1             3759 non-null   object
#  10  Genre 2             3384 non-null   object
#  11  Genre 3             2347 non-null   object
#  12  Gross Worldwide     2767 non-null   float64
#  13  Duration            3759 non-null   float64
#  14  Currency            3759 non-null   object
# dtypes: float64(3), int32(1), int64(2), object(9)
# memory usage: 425.9+ KB

# %%
#Converting other currency to dollar based on conversion rate
def adj_budget(oscars):
    if oscars['Currency'] == '$':
        return oscars['Budget']
    elif oscars['Currency'] == '£':
        return oscars['Budget'] * 1.23
    elif oscars['Currency'] == '€':
        return oscars['Budget'] * 1.07
    elif oscars['Currency'] == 'n':
        return oscars['Budget']

# %%
oscars['adj_Budget'] = oscars.apply(adj_budget, axis = 1)

# %%
oscars.head()
# Out:
#    movie_number       Title  Date Viewership_Rating  IMDb Rating  \
# 0             1       Wings  1927             PG-13          7.6
# 1             1       Wings  1927             PG-13          7.6
# 2             2  7th Heaven  1927         Not Rated          7.6
# 3             2  7th Heaven  1927         Not Rated          7.6
# 4             2  7th Heaven  1927         Not Rated          7.6
#
#   Country of Origin                  Production Company   Budget  \
# 0     United States  Paramount Famous Lasky Corporation  2000000
# 1     United States  Paramount Famous Lasky Corporation  2000000
# 2     United States            Frank Borzage Production  1300000
# 3     United States            Frank Borzage Production  1300000
# 4     United States            Frank Borzage Production  1300000
#
#                          nominations Genre 1  Genre 2 Genre 3  \
# 0           Best Picture, Production   Drama  Romance     War
# 1  Best Effects, Engineering Effects   Drama  Romance     War
# 2           Best Picture, Production   Drama  Romance     NaN
# 3     Best Actress in a Leading Role   Drama  Romance     NaN
# 4    Best Director, Dramatic Picture   Drama  Romance     NaN
#
#    Gross Worldwide  Duration Currency  adj_Budget
# 0            746.0    144.00        $   2000000.0
# 1            746.0    144.00        $   2000000.0
# 2              NaN    130.76        $   1300000.0
# 3              NaN    130.76        $   1300000.0
# 4              NaN    130.76        $   1300000.0

# %% [markdown]
# #### *Now that we have converted the budget into readable values Its now time to fill in the missing values(which are zeros as place holder)*

# %%
non_zero = oscars[oscars['adj_Budget'] != 0 ]
non_zero = non_zero.groupby('Date').agg({'adj_Budget':np.mean}).round(2).reset_index()# Making sure the zeros, which are just null values, dont skew the data
non_zero.head() # Here I want to average the budget by year
# Out:
#    Date  adj_Budget
# 0  1927  1500000.00
# 1  1928  1000000.00
# 2  1929   559666.67
# 3  1930   651563.67
# 4  1931  1294848.44

# %%
round(np.mean(oscars['adj_Budget'] [(oscars['Date'] == 1931) & (oscars['adj_Budget'] !=0)]),2) 
#checking one particlur date if I could average it.Since it works I can easily place it in my for loop in the next cell
# Out:
# 1294848.44

# %%
for x in oscars['Date'].unique(): # Replacing every instance of nulls(now zeros) with average budget of that year
    oscars.loc[(oscars['adj_Budget'] == 0) & (oscars['Date'] == x), 'adj_Budget'] = round(np.mean(oscars['adj_Budget'] [(oscars['Date'] == x) & (oscars['adj_Budget'] !=0)]),2)

# %%
oscars.head(100)
# Out:
#     movie_number                              Title  Date Viewership_Rating  \
# 0              1                              Wings  1927             PG-13
# 1              1                              Wings  1927             PG-13
# 2              2                         7th Heaven  1927         Not Rated
# 3              2                         7th Heaven  1927         Not Rated
# 4              2                         7th Heaven  1927         Not Rated
# 5              2                         7th Heaven  1927         Not Rated
# 6              2                         7th Heaven  1927         Not Rated
# 7              3                         The Racket  1928            Passed
# 8              4                The Broadway Melody  1929            Passed
# 9              4                The Broadway Melody  1929            Passed
# 10             4                The Broadway Melody  1929            Passed
# 11             5                     In Old Arizona  1928            Passed
# 12             5                     In Old Arizona  1928            Passed
# 13             5                     In Old Arizona  1928            Passed
# 14             5                     In Old Arizona  1928            Passed
# 15             5                     In Old Arizona  1928            Passed
# 16             6                        The Patriot  1928         Not Rated
# 17             6                        The Patriot  1928         Not Rated
# 18             6                        The Patriot  1928         Not Rated
# 19             6                        The Patriot  1928         Not Rated
# 20             6                        The Patriot  1928         Not Rated
# 21             7        The Hollywood Revue of 1929  1929            Passed
# 22             8                              Alibi  1929            Passed
# 23             8                              Alibi  1929            Passed
# 24             8                              Alibi  1929            Passed
# 25             9     All Quiet on the Western Front  1930            Passed
# 26             9     All Quiet on the Western Front  1930            Passed
# 27             9     All Quiet on the Western Front  1930            Passed
# 28             9     All Quiet on the Western Front  1930            Passed
# 29            10                           Disraeli  1929            Passed
# 30            10                           Disraeli  1929            Passed
# 31            10                           Disraeli  1929            Passed
# 32            11                    The Love Parade  1929            Passed
# 33            11                    The Love Parade  1929            Passed
# 34            11                    The Love Parade  1929            Passed
# 35            11                    The Love Parade  1929            Passed
# 36            11                    The Love Parade  1929            Passed
# 37            11                    The Love Parade  1929            Passed
# 38            12                      The Big House  1930            Passed
# 39            12                      The Big House  1930            Passed
# 40            12                      The Big House  1930            Passed
# 41            12                      The Big House  1930            Passed
# 42            13                       The Divorcee  1930            Passed
# 43            13                       The Divorcee  1930            Passed
# 44            13                       The Divorcee  1930            Passed
# 45            13                       The Divorcee  1930            Passed
# 46            14                           Cimarron  1931            Passed
# 47            14                           Cimarron  1931            Passed
# 48            14                           Cimarron  1931            Passed
# 49            14                           Cimarron  1931            Passed
# 50            14                           Cimarron  1931            Passed
# 51            14                           Cimarron  1931            Passed
# 52            14                           Cimarron  1931            Passed
# 53            15                         East Lynne  1931            Passed
# 54            16                     The Front Page  1931          Approved
# 55            16                     The Front Page  1931          Approved
# 56            16                     The Front Page  1931          Approved
# 57            17                             Skippy  1931            Passed
# 58            17                             Skippy  1931            Passed
# 59            17                             Skippy  1931            Passed
# 60            17                             Skippy  1931            Passed
# 61            18                        Trader Horn  1931            Passed
# 62            19                        Grand Hotel  1932         Not Rated
# 63            20                         Arrowsmith  1931          Approved
# 64            20                         Arrowsmith  1931          Approved
# 65            20                         Arrowsmith  1931          Approved
# 66            20                         Arrowsmith  1931          Approved
# 67            21                           Bad Girl  1931            Passed
# 68            21                           Bad Girl  1931            Passed
# 69            21                           Bad Girl  1931            Passed
# 70            22                          The Champ  1931            Passed
# 71            22                          The Champ  1931            Passed
# 72            22                          The Champ  1931            Passed
# 73            22                          The Champ  1931            Passed
# 74            23                    Five Star Final  1931         Not Rated
# 75            24                  One Hour with You  1932            Passed
# 76            25                   Shanghai Express  1932          Approved
# 77            25                   Shanghai Express  1932          Approved
# 78            25                   Shanghai Express  1932          Approved
# 79            26             The Smiling Lieutenant  1931            Passed
# 80            27                          Cavalcade  1933            Passed
# 81            27                          Cavalcade  1933            Passed
# 82            27                          Cavalcade  1933            Passed
# 83            27                          Cavalcade  1933            Passed
# 84            28                 A Farewell to Arms  1932           Unrated
# 85            28                 A Farewell to Arms  1932           Unrated
# 86            28                 A Farewell to Arms  1932           Unrated
# 87            28                 A Farewell to Arms  1932           Unrated
# 88            29                        42nd Street  1933            Passed
# 89            29                        42nd Street  1933            Passed
# 90            30  I Am a Fugitive from a Chain Gang  1932            Passed
# 91            30  I Am a Fugitive from a Chain Gang  1932            Passed
# 92            30  I Am a Fugitive from a Chain Gang  1932            Passed
# 93            31                    Smilin' Through  1932          Approved
# 94            32                     Lady for a Day  1933            Passed
# 95            32                     Lady for a Day  1933            Passed
# 96            32                     Lady for a Day  1933            Passed
# 97            32                     Lady for a Day  1933            Passed
# 98            33                       Little Women  1933            Passed
# 99            33                       Little Women  1933            Passed
#
#     IMDb Rating Country of Origin                  Production Company  \
# 0          7.60     United States  Paramount Famous Lasky Corporation
# 1          7.60     United States  Paramount Famous Lasky Corporation
# 2          7.60     United States            Frank Borzage Production
# 3          7.60     United States            Frank Borzage Production
# 4          7.60     United States            Frank Borzage Production
# 5          7.60     United States            Frank Borzage Production
# 6          7.60     United States            Frank Borzage Production
# 7          6.60     United States                   The Caddo Company
# 8          5.60     United States           Metro-Goldwyn-Mayer (MGM)
# 9          5.60     United States           Metro-Goldwyn-Mayer (MGM)
# 10         5.60     United States           Metro-Goldwyn-Mayer (MGM)
# 11         5.50     United States                Fox Film Corporation
# 12         5.50     United States                Fox Film Corporation
# 13         5.50     United States                Fox Film Corporation
# 14         5.50     United States                Fox Film Corporation
# 15         5.50     United States                Fox Film Corporation
# 16         7.62     United States                  Paramount Pictures
# 17         7.62     United States                  Paramount Pictures
# 18         7.62     United States                  Paramount Pictures
# 19         7.62     United States                  Paramount Pictures
# 20         7.62     United States                  Paramount Pictures
# 21         5.80     United States           Metro-Goldwyn-Mayer (MGM)
# 22         5.70     United States                 Feature Productions
# 23         5.70     United States                 Feature Productions
# 24         5.70     United States                 Feature Productions
# 25         8.10     United States                  Universal Pictures
# 26         8.10     United States                  Universal Pictures
# 27         8.10     United States                  Universal Pictures
# 28         8.10     United States                  Universal Pictures
# 29         6.10     United States                        Warner Bros.
# 30         6.10     United States                        Warner Bros.
# 31         6.10     United States                        Warner Bros.
# 32         7.00     United States                  Paramount Pictures
# 33         7.00     United States                  Paramount Pictures
# 34         7.00     United States                  Paramount Pictures
# 35         7.00     United States                  Paramount Pictures
# 36         7.00     United States                  Paramount Pictures
# 37         7.00     United States                  Paramount Pictures
# 38         7.10     United States           Metro-Goldwyn-Mayer (MGM)
# 39         7.10     United States           Metro-Goldwyn-Mayer (MGM)
# 40         7.10     United States           Metro-Goldwyn-Mayer (MGM)
# 41         7.10     United States           Metro-Goldwyn-Mayer (MGM)
# 42         6.70     United States           Metro-Goldwyn-Mayer (MGM)
# 43         6.70     United States           Metro-Goldwyn-Mayer (MGM)
# 44         6.70     United States           Metro-Goldwyn-Mayer (MGM)
# 45         6.70     United States           Metro-Goldwyn-Mayer (MGM)
# 46         5.80     United States                  RKO Radio Pictures
# 47         5.80     United States                  RKO Radio Pictures
# 48         5.80     United States                  RKO Radio Pictures
# 49         5.80     United States                  RKO Radio Pictures
# 50         5.80     United States                  RKO Radio Pictures
# 51         5.80     United States                  RKO Radio Pictures
# 52         5.80     United States                  RKO Radio Pictures
# 53         5.90     United States                Fox Film Corporation
# 54         6.70     United States                   The Caddo Company
# 55         6.70     United States                   The Caddo Company
# 56         6.70     United States                   The Caddo Company
# 57         6.30     United States                  Paramount Pictures
# 58         6.30     United States                  Paramount Pictures
# 59         6.30     United States                  Paramount Pictures
# 60         6.30     United States                  Paramount Pictures
# 61         6.20     United States           Metro-Goldwyn-Mayer (MGM)
# 62         7.30     United States           Metro-Goldwyn-Mayer (MGM)
# 63         6.20     United States               John Ford Productions
# 64         6.20     United States               John Ford Productions
# 65         6.20     United States               John Ford Productions
# 66         6.20     United States               John Ford Productions
# 67         6.50     United States            Frank Borzage Production
# 68         6.50     United States            Frank Borzage Production
# 69         6.50     United States            Frank Borzage Production
# 70         7.30     United States           Metro-Goldwyn-Mayer (MGM)
# 71         7.30     United States           Metro-Goldwyn-Mayer (MGM)
# 72         7.30     United States           Metro-Goldwyn-Mayer (MGM)
# 73         7.30     United States           Metro-Goldwyn-Mayer (MGM)
# 74         7.30     United States             First National Pictures
# 75         7.10     United States                  Paramount Pictures
# 76         7.30     United States                  Paramount Pictures
# 77         7.30     United States                  Paramount Pictures
# 78         7.30     United States                  Paramount Pictures
# 79         7.20     United States                  Paramount Pictures
# 80         5.80     United States                Fox Film Corporation
# 81         5.80     United States                Fox Film Corporation
# 82         5.80     United States                Fox Film Corporation
# 83         5.80     United States                Fox Film Corporation
# 84         6.40     United States                  Paramount Pictures
# 85         6.40     United States                  Paramount Pictures
# 86         6.40     United States                  Paramount Pictures
# 87         6.40     United States                  Paramount Pictures
# 88         7.30     United States                        Warner Bros.
# 89         7.30     United States                        Warner Bros.
# 90         8.20     United States                        Warner Bros.
# 91         8.20     United States                        Warner Bros.
# 92         8.20     United States                        Warner Bros.
# 93         6.90     United States           Metro-Goldwyn-Mayer (MGM)
# 94         7.40     United States                   Columbia Pictures
# 95         7.40     United States                   Columbia Pictures
# 96         7.40     United States                   Columbia Pictures
# 97         7.40     United States                   Columbia Pictures
# 98         7.20     United States                  RKO Radio Pictures
# 99         7.20     United States                  RKO Radio Pictures
#
#      Budget                        nominations    Genre 1    Genre 2  \
# 0   2000000           Best Picture, Production      Drama    Romance
# 1   2000000  Best Effects, Engineering Effects      Drama    Romance
# 2   1300000           Best Picture, Production      Drama    Romance
# 3   1300000     Best Actress in a Leading Role      Drama    Romance
# 4   1300000    Best Director, Dramatic Picture      Drama    Romance
# 5   1300000           Best Writing, Adaptation      Drama    Romance
# 6   1300000                 Best Art Direction      Drama    Romance
# 7         0           Best Picture, Production      Crime      Drama
# 8    379000                       Best Picture      Drama    Musical
# 9    379000     Best Actress in a Leading Role      Drama    Musical
# 10   379000                      Best Director      Drama    Musical
# 11        0                       Best Picture      Drama    Western
# 12        0       Best Actor in a Leading Role      Drama    Western
# 13        0                      Best Director      Drama    Western
# 14        0          Best Writing, Achievement      Drama    Western
# 15        0                Best Cinematography      Drama    Western
# 16  1000000                       Best Picture      Drama    History
# 17  1000000       Best Actor in a Leading Role      Drama    History
# 18  1000000                      Best Director      Drama    History
# 19  1000000          Best Writing, Achievement      Drama    History
# 20  1000000                 Best Art Direction      Drama    History
# 21        0                       Best Picture     Comedy      Music
# 22        0                       Best Picture     Action      Crime
# 23        0       Best Actor in a Leading Role     Action      Crime
# 24        0                 Best Art Direction     Action      Crime
# 25  1200000                       Best Picture      Drama        War
# 26  1200000                      Best Director      Drama        War
# 27  1200000          Best Writing, Achievement      Drama        War
# 28  1200000                Best Cinematography      Drama        War
# 29        0                       Best Picture  Biography      Drama
# 30        0       Best Actor in a Leading Role  Biography      Drama
# 31        0          Best Writing, Achievement  Biography      Drama
# 32   650000                       Best Picture     Comedy    Musical
# 33   650000       Best Actor in a Leading Role     Comedy    Musical
# 34   650000                      Best Director     Comedy    Musical
# 35   650000                Best Cinematography     Comedy    Musical
# 36   650000                 Best Art Direction     Comedy    Musical
# 37   650000              Best Sound, Recording     Comedy    Musical
# 38   414000                       Best Picture      Crime      Drama
# 39   414000       Best Actor in a Leading Role      Crime      Drama
# 40   414000          Best Writing, Achievement      Crime      Drama
# 41   414000              Best Sound, Recording      Crime      Drama
# 42   340691                       Best Picture    Romance      Drama
# 43   340691     Best Actress in a Leading Role    Romance      Drama
# 44   340691                      Best Director    Romance      Drama
# 45   340691          Best Writing, Achievement    Romance      Drama
# 46  1433000                       Best Picture      Drama      Music
# 47  1433000       Best Actor in a Leading Role      Drama      Music
# 48  1433000     Best Actress in a Leading Role      Drama      Music
# 49  1433000                      Best Director      Drama      Music
# 50  1433000           Best Writing, Adaptation      Drama      Music
# 51  1433000                Best Cinematography      Drama      Music
# 52  1433000                 Best Art Direction      Drama      Music
# 53        0                       Best Picture      Drama    Romance
# 54        0                       Best Picture     Comedy      Crime
# 55        0       Best Actor in a Leading Role     Comedy      Crime
# 56        0                      Best Director     Comedy      Crime
# 57        0                       Best Picture     Comedy      Drama
# 58        0       Best Actor in a Leading Role     Comedy      Drama
# 59        0                      Best Director     Comedy      Drama
# 60        0           Best Writing, Adaptation     Comedy      Drama
# 61  1312636                       Best Picture     Action  Adventure
# 62   700000                       Best Picture      Drama    Romance
# 63        0                       Best Picture      Drama        NaN
# 64        0           Best Writing, Adaptation      Drama        NaN
# 65        0                Best Cinematography      Drama        NaN
# 66        0                 Best Art Direction      Drama        NaN
# 67        0                       Best Picture      Drama    Romance
# 68        0                      Best Director      Drama    Romance
# 69        0           Best Writing, Adaptation      Drama    Romance
# 70        0                       Best Picture      Drama     Family
# 71        0       Best Actor in a Leading Role      Drama     Family
# 72        0                      Best Director      Drama     Family
# 73        0       Best Writing, Original Story      Drama     Family
# 74   310000                       Best Picture      Crime      Drama
# 75        0                       Best Picture     Comedy    Musical
# 76        0                       Best Picture  Adventure      Drama
# 77        0                      Best Director  Adventure      Drama
# 78        0                Best Cinematography  Adventure      Drama
# 79        0                       Best Picture     Comedy    Musical
# 80  1180280                       Best Picture      Drama    Romance
# 81  1180280     Best Actress in a Leading Role      Drama    Romance
# 82  1180280                      Best Director      Drama    Romance
# 83  1180280                 Best Art Direction      Drama    Romance
# 84   799520                       Best Picture      Drama    Romance
# 85   799520                Best Cinematography      Drama    Romance
# 86   799520                 Best Art Direction      Drama    Romance
# 87   799520              Best Sound, Recording      Drama    Romance
# 88   439000                       Best Picture     Comedy      Drama
# 89   439000              Best Sound, Recording     Comedy      Drama
# 90   195845                       Best Picture      Crime      Drama
# 91   195845       Best Actor in a Leading Role      Crime      Drama
# 92   195845              Best Sound, Recording      Crime      Drama
# 93   851000                       Best Picture      Drama    Romance
# 94        0                       Best Picture     Comedy      Drama
# 95        0     Best Actress in a Leading Role     Comedy      Drama
# 96        0                      Best Director     Comedy      Drama
# 97        0           Best Writing, Adaptation     Comedy      Drama
# 98   424000                       Best Picture      Drama     Family
# 99   424000                      Best Director      Drama     Family
#
#       Genre 3  Gross Worldwide  Duration Currency  adj_Budget
# 0         War            746.0    144.00        $  2000000.00
# 1         War            746.0    144.00        $  2000000.00
# 2         NaN              NaN    130.76        $  1300000.00
# 3         NaN              NaN    130.76        $  1300000.00
# 4         NaN              NaN    130.76        $  1300000.00
# 5         NaN              NaN    130.76        $  1300000.00
# 6         NaN              NaN    130.76        $  1300000.00
# 7   Film-Noir              NaN     84.00        n  1000000.00
# 8     Romance              NaN    100.00        $   379000.00
# 9     Romance              NaN    100.00        $   379000.00
# 10    Romance              NaN    100.00        $   379000.00
# 11        NaN              NaN     95.00        n  1000000.00
# 12        NaN              NaN     95.00        n  1000000.00
# 13        NaN              NaN     95.00        n  1000000.00
# 14        NaN              NaN     95.00        n  1000000.00
# 15        NaN              NaN     95.00        n  1000000.00
# 16   Thriller              NaN    130.76        $  1000000.00
# 17   Thriller              NaN    130.76        $  1000000.00
# 18   Thriller              NaN    130.76        $  1000000.00
# 19   Thriller              NaN    130.76        $  1000000.00
# 20   Thriller              NaN    130.76        $  1000000.00
# 21        NaN        5277780.0    130.00        n   559666.67
# 22    Romance              NaN     91.00        n   559666.67
# 23    Romance              NaN     91.00        n   559666.67
# 24    Romance              NaN     91.00        n   559666.67
# 25        NaN              NaN    152.00        $  1200000.00
# 26        NaN              NaN    152.00        $  1200000.00
# 27        NaN              NaN    152.00        $  1200000.00
# 28        NaN              NaN    152.00        $  1200000.00
# 29    History              NaN     90.00        n   559666.67
# 30    History              NaN     90.00        n   559666.67
# 31    History              NaN     90.00        n   559666.67
# 32    Romance              NaN    107.00        $   650000.00
# 33    Romance              NaN    107.00        $   650000.00
# 34    Romance              NaN    107.00        $   650000.00
# 35    Romance              NaN    107.00        $   650000.00
# 36    Romance              NaN    107.00        $   650000.00
# 37    Romance              NaN    107.00        $   650000.00
# 38   Thriller              NaN     87.00        $   414000.00
# 39   Thriller              NaN     87.00        $   414000.00
# 40   Thriller              NaN     87.00        $   414000.00
# 41   Thriller              NaN     87.00        $   414000.00
# 42        NaN              NaN     84.00        $   340691.00
# 43        NaN              NaN     84.00        $   340691.00
# 44        NaN              NaN     84.00        $   340691.00
# 45        NaN              NaN     84.00        $   340691.00
# 46    Western              NaN    123.00        $  1433000.00
# 47    Western              NaN    123.00        $  1433000.00
# 48    Western              NaN    123.00        $  1433000.00
# 49    Western              NaN    123.00        $  1433000.00
# 50    Western              NaN    123.00        $  1433000.00
# 51    Western              NaN    123.00        $  1433000.00
# 52    Western              NaN    123.00        $  1433000.00
# 53        NaN              NaN    102.00        n  1294848.44
# 54      Drama              NaN    101.00        n  1294848.44
# 55      Drama              NaN    101.00        n  1294848.44
# 56      Drama              NaN    101.00        n  1294848.44
# 57     Family              NaN     85.00        n  1294848.44
# 58     Family              NaN     85.00        n  1294848.44
# 59     Family              NaN     85.00        n  1294848.44
# 60     Family              NaN     85.00        n  1294848.44
# 61      Drama              NaN    122.00        $  1312636.00
# 62        NaN              NaN    112.00        $   700000.00
# 63        NaN              NaN    108.00        n  1294848.44
# 64        NaN              NaN    108.00        n  1294848.44
# 65        NaN              NaN    108.00        n  1294848.44
# 66        NaN              NaN    108.00        n  1294848.44
# 67        NaN              NaN     90.00        n  1294848.44
# 68        NaN              NaN     90.00        n  1294848.44
# 69        NaN              NaN     90.00        n  1294848.44
# 70      Sport              NaN     86.00        n  1294848.44
# 71      Sport              NaN     86.00        n  1294848.44
# 72      Sport              NaN     86.00        n  1294848.44
# 73      Sport              NaN     86.00        n  1294848.44
# 74      Music              NaN     89.00        $   310000.00
# 75    Romance              NaN     78.00        n   592957.22
# 76  Film-Noir              NaN     82.00        n   592957.22
# 77  Film-Noir              NaN     82.00        n   592957.22
# 78  Film-Noir              NaN     82.00        n   592957.22
# 79    Romance              NaN     93.00        n  1294848.44
# 80        War              NaN    112.00        $  1180280.00
# 81        War              NaN    112.00        $  1180280.00
# 82        War              NaN    112.00        $  1180280.00
# 83        War              NaN    112.00        $  1180280.00
# 84        War              NaN     80.00        $   799520.00
# 85        War              NaN     80.00        $   799520.00
# 86        War              NaN     80.00        $   799520.00
# 87        War              NaN     80.00        $   799520.00
# 88      Music           1600.0     89.00        $   439000.00
# 89      Music           1600.0     89.00        $   439000.00
# 90  Film-Noir              NaN     92.00        $   195845.00
# 91  Film-Noir              NaN     92.00        $   195845.00
# 92  Film-Noir              NaN     92.00        $   195845.00
# 93        NaN              NaN     98.00        $   851000.00
# 94        NaN              NaN     96.00        n   601560.00
# 95        NaN              NaN     96.00        n   601560.00
# 96        NaN              NaN     96.00        n   601560.00
# 97        NaN              NaN     96.00        n   601560.00
# 98    Romance              NaN    115.00        $   424000.00
# 99    Romance              NaN    115.00        $   424000.00

# %%
oscars[oscars['adj_Budget']==0] #No more nulls
# Out:
# Empty DataFrame
# Columns: [movie_number, Title, Date, Viewership_Rating, IMDb Rating, Country of Origin, Production Company, Budget, nominations, Genre 1, Genre 2, Genre 3, Gross Worldwide, Duration, Currency, adj_Budget]
# Index: []

# %% [markdown]
# ### Now that we have filled in all null values within the adj_budgt with the average budget of that year. We can begin to clean up all of the place holder columns

# %%
#We can get rid of Budget
oscars = oscars.drop('Budget', axis=1)
#We can also get rid of Currecy
oscars = oscars.drop('Currency', axis=1)

# %%
oscars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3759 entries, 0 to 3758
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movie_number        3759 non-null   int64
#  1   Title               3759 non-null   object
#  2   Date                3759 non-null   int64
#  3   Viewership_Rating   3759 non-null   object
#  4   IMDb Rating         3759 non-null   float64
#  5   Country of Origin   3759 non-null   object
#  6   Production Company  3759 non-null   object
#  7   nominations         3759 non-null   object
#  8   Genre 1             3759 non-null   object
#  9   Genre 2             3384 non-null   object
#  10  Genre 3             2347 non-null   object
#  11  Gross Worldwide     2767 non-null   float64
#  12  Duration            3759 non-null   float64
#  13  adj_Budget          3759 non-null   float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 411.3+ KB

# %% [markdown]
# ### Cleaning up Genre columns

# %%
oscars[['Genre 1','Genre 2','Genre 3']].head()
# Out:
#   Genre 1  Genre 2 Genre 3
# 0   Drama  Romance     War
# 1   Drama  Romance     War
# 2   Drama  Romance     NaN
# 3   Drama  Romance     NaN
# 4   Drama  Romance     NaN

# %%
oscars['Genre 1'].isnull().value_counts()
# Out:
# False    3759
# Name: Genre 1, dtype: int64

# %%
oscars['Genre 2'].isnull().value_counts()
# Out:
# False    3384
# True      375
# Name: Genre 2, dtype: int64

# %% [markdown]
# #### While all movies have at least one genre listed, others do not

# %%
oscars['Genre 2'].fillna(oscars['Genre 1'], inplace=True) #If genre 2 is null fill it with genre 1

# %%
oscars[['Genre 1','Genre 2','Genre 3']].head(10)
# Out:
#   Genre 1  Genre 2    Genre 3
# 0   Drama  Romance        War
# 1   Drama  Romance        War
# 2   Drama  Romance        NaN
# 3   Drama  Romance        NaN
# 4   Drama  Romance        NaN
# 5   Drama  Romance        NaN
# 6   Drama  Romance        NaN
# 7   Crime    Drama  Film-Noir
# 8   Drama  Musical    Romance
# 9   Drama  Musical    Romance

# %%
oscars['Genre 3'].isnull().value_counts()
# Out:
# False    2347
# True     1412
# Name: Genre 3, dtype: int64

# %%
oscars['Genre 3'].fillna(oscars['Genre 2'], inplace=True) #If genre 3 is null fill it with genre 2

# %%
oscars[['Genre 1','Genre 2','Genre 3']].head(10)
# Out:
#   Genre 1  Genre 2    Genre 3
# 0   Drama  Romance        War
# 1   Drama  Romance        War
# 2   Drama  Romance    Romance
# 3   Drama  Romance    Romance
# 4   Drama  Romance    Romance
# 5   Drama  Romance    Romance
# 6   Drama  Romance    Romance
# 7   Crime    Drama  Film-Noir
# 8   Drama  Musical    Romance
# 9   Drama  Musical    Romance

# %%
oscars['Genre 3'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# ## Gross Worldwide
# ### There is no easy way to fill in all the null values. Furthermore it might be biased towards later years since they have the advangtage of a global market. Its best to just drop this variable

# %%
oscars = oscars.drop('Gross Worldwide', axis=1)

# %% [markdown]
# # Changing the nominations column
# #### This column was by far the most diffcult to fix. However fixing this last column will not only mean finishing the cleaning portion of the EDA but also be able to fix the duplication problem as stated in the very beginning.
# #### In order to see what I mean by duplication problem look at the next cell

# %%
oscars[['Title','nominations']].head() # As we can see values are being repeated because multiple nominations were granted to the same movie
# Out:
#         Title                        nominations
# 0       Wings           Best Picture, Production
# 1       Wings  Best Effects, Engineering Effects
# 2  7th Heaven           Best Picture, Production
# 3  7th Heaven     Best Actress in a Leading Role
# 4  7th Heaven    Best Director, Dramatic Picture

# %%
oscars.head() ## Here you can cleary see that the movie 'Wings' has two identical rows expect for the nomination column
# Out:
#    movie_number       Title  Date Viewership_Rating  IMDb Rating  \
# 0             1       Wings  1927             PG-13          7.6
# 1             1       Wings  1927             PG-13          7.6
# 2             2  7th Heaven  1927         Not Rated          7.6
# 3             2  7th Heaven  1927         Not Rated          7.6
# 4             2  7th Heaven  1927         Not Rated          7.6
#
#   Country of Origin                  Production Company  \
# 0     United States  Paramount Famous Lasky Corporation
# 1     United States  Paramount Famous Lasky Corporation
# 2     United States            Frank Borzage Production
# 3     United States            Frank Borzage Production
# 4     United States            Frank Borzage Production
#
#                          nominations Genre 1  Genre 2  Genre 3  Duration  \
# 0           Best Picture, Production   Drama  Romance      War    144.00
# 1  Best Effects, Engineering Effects   Drama  Romance      War    144.00
# 2           Best Picture, Production   Drama  Romance  Romance    130.76
# 3     Best Actress in a Leading Role   Drama  Romance  Romance    130.76
# 4    Best Director, Dramatic Picture   Drama  Romance  Romance    130.76
#
#    adj_Budget
# 0   2000000.0
# 1   2000000.0
# 2   1300000.0
# 3   1300000.0
# 4   1300000.0

# %% [markdown]
# ### The reason I wante to fix this problem is that a normlized dataset is much easier to read. For humans and computers.
# #### *Learn more about normalization at: https://www.studytonight.com/dbms/database-normalization.php

# %% [markdown]
# ### In order to fix the column I will need to place every unqiue instance of nomination as its own column. Then fill it with a boolean data type. I want to see every movie and whether or not they have earned x nomination categorized by TRUE or FALSE.
#
# #### A rough example:

# %%
img = Image.open('nom_example.png')
plt.imshow(img)

# %%
noms_arry = oscars['nominations'].unique() # First lets look at the all nominations
noms_arry.tolist()
# Out:
# ['Best Picture, Production',
#  'Best Effects, Engineering Effects',
#  'Best Actress in a Leading Role',
#  'Best Director, Dramatic Picture',
#  'Best Writing, Adaptation',
#  'Best Art Direction',
#  'Best Picture',
#  'Best Director',
#  'Best Actor in a Leading Role',
#  'Best Writing, Achievement',
#  'Best Cinematography',
#  'Best Sound, Recording',
#  'Best Writing, Original Story',
#  'Best Film Editing',
#  'Best Assistant Director',
#  'Best Music, Original Song',
#  'Best Music, Score',
#  'Best Writing, Screenplay',
#  'Best Dance Direction',
#  'Best Actress in a Supporting Role',
#  'Best Actor in a Supporting Role',
#  'Best Music, Original Score',
#  'Best Music, Scoring',
#  'Best Cinematography, Color',
#  'Best Effects, Special Effects',
#  'Best Cinematography, Black-and-White',
#  'Best Art Direction, Black-and-White',
#  'Best Writing, Original Screenplay',
#  'Best Art Direction-Interior Decoration, Black-and-White',
#  'Best Music, Scoring of a Dramatic Picture',
#  'Best Art Direction-Interior Decoration, Color',
#  'Best Music, Scoring of a Dramatic or Comedy Picture',
#  'Best Music, Scoring of a Musical Picture',
#  'Best Art Direction-Set Decoration, Black-and-White',
#  'Best Costume Design, Black-and-White',
#  'Best Writing, Motion Picture Story',
#  'Best Art Direction-Set Decoration, Color',
#  'Best Writing, Story and Screenplay',
#  'Best Costume Design, Color',
#  'Best Writing, Best Screenplay - Adapted',
#  'Best Writing, Screenplay Based on Material from Another Medium',
#  'Best Art Direction-Set Decoration',
#  'Best Art Direction-Set Decoration, Black-and-White or Color',
#  'Best Costume Design, Black-and-White or Color',
#  'Best Writing, Story and Screenplay - Written Directly for the Screen',
#  'Best Sound',
#  'Best Music, Score - Substantially Original',
#  'Best Music, Scoring of Music, Adaptation or Treatment',
#  'Best Effects, Special Visual Effects',
#  'Best Music, Substantially Original Score',
#  'Best Music, Original Music Score',
#  'Best Effects, Sound Effects',
#  'Best Costume Design',
#  'Best Music, Score of a Musical Picture (Original or Adaptation)',
#  'Best Music, Original Score for a Motion Picture (not a Musical)',
#  'Best Writing, Story and Screenplay Based on Material Not Previously Published or Produced',
#  'Best Foreign Language Film',
#  'Best Writing, Story and Screenplay Based on Factual Material or Material Not Previously Published or Produced',
#  'Best Music, Scoring Adaptation and Original Song Score',
#  'Best Music, Original Dramatic Score',
#  'Best Music, Scoring Original Song Score and/or Adaptation',
#  'Best Writing, Screenplay Adapted From Other Material',
#  'Best Writing, Screenplay Written Directly for the Screen',
#  'Best Music, Original Song Score and Its Adaptation or Best Adaptation Score',
#  'Best Effects, Visual Effects',
#  'Best Makeup',
#  'Best Effects, Sound Effects Editing',
#  'Best Writing, Screenplay Based on Material Previously Produced or Published',
#  'Best Music, Original Musical or Comedy Score',
#  'Best Writing, Adapted Screenplay',
#  'Best Sound Editing',
#  'Best Visual Effects',
#  'Best Sound Mixing',
#  'Best Motion Picture of the Year',
#  'Best Performance by an Actor in a Leading Role',
#  'Best Performance by an Actress in a Leading Role',
#  'Best Performance by an Actor in a Supporting Role',
#  'Best Achievement in Directing',
#  'Best Achievement in Film Editing',
#  'Best Performance by an Actress in a Supporting Role',
#  'Best Achievement in Cinematography',
#  'Best Achievement in Art Direction',
#  'Best Achievement in Costume Design',
#  'Best Achievement in Sound Mixing',
#  'Best Achievement in Music Written for Motion Pictures, Original Score',
#  'Best Achievement in Music Written for Motion Pictures, Original Song',
#  'Best Achievement in Sound Editing',
#  'Best Achievement in Makeup',
#  'Best Achievement in Visual Effects',
#  'Best Animated Feature Film of the Year',
#  'Best Foreign Language Film of the Year',
#  'Best Achievement in Makeup and Hairstyling',
#  'Best Achievement in Production Design',
#  'Best Achievement in Music Written for Motion Pictures (Original Score)',
#  'Best Adapted Screenplay',
#  'Best Original Screenplay',
#  'Best Achievement in Music Written for Motion Pictures (Original Song)',
#  'Best International Feature Film']

# %%
n = len(noms_arry.tolist())
print('There are', n, 'nominations')
# Out:
# There are 98 nominations

# %% [markdown]
# ## 98 nominations seems like alot. Some exploring will need to be done
# ### As of today there are 24 categories up for nominations(story and original screenplay combined).
# ### Furthermore 10 have been reitired as a category
# #### *This info was gathered from https://www.awardsandshows.com/features/awards-categories-1.html

# %%
#Since this data was gathered from a list of movies that were nominated for best picture. We should remove that nomination.
oscars_noms = oscars.drop(oscars[oscars.nominations.isin([
    "Best Picture, Production", "Best Picture","Best Motion Picture of the Year",'Best Picture, Production'])].index) # Removing rows

# %%
# Removing 10 retired categoires
retired = pd.read_csv(r"C:\Users\kylep\Documents\Work things\Projects\Python\Oscars\retired_osc_cat.csv")
retired.head(10)
# Out:
#                                          category
# 0                         Best Assistant Director
# 1                            Best Dance Direction
# 2                        Best Engineering Effects
# 3           Best Original Musical or Comedy Score
# 4            Best Score - Adaptation or Treatment
# 5                         Best Short Film - Color
# 6           Best Short Film - Live Action 2 Reels
# 7                              Best Title Writing
# 8  Best Unique and Artistic Quality of Production
# 9                            Short Film - Novelty

# %%
oscars_noms = oscars_noms.drop(oscars_noms[oscars_noms.nominations.isin([
    'Best Assistant Director','Best Effects, Engineering Effects','Best Dance Direction',
    'Best Music, Scoring of Music, Adaptation or Treatment','Best Music, Scoring of a Dramatic or Comedy Picture',
    'Best Music, Scoring of a Musical Picture'
    
])].index)

# %% [markdown]
# ### Since there is no easy way of consolidating all nominations I will go through all 25 categories and see if they are named something else and combine them.
#
# #### My process was simple:
#  - Look up the unqiue occurrence of nomination based on key word
#  - Look at the history of nomination and see if there has been any changes to the award throughout the years
#  - Make the change in one massive cell, that contains all the other changes

# %%
#Best actor in a leading role
cat1 = oscars_noms[oscars_noms.nominations.str.contains("Actor")]
cat1['nominations'].unique()
# Out:
# array(['Best Actor in a Leading Role', 'Best Actor in a Supporting Role',
#        'Best Performance by an Actor in a Leading Role',
#        'Best Performance by an Actor in a Supporting Role'], dtype=object)

# %%
#Best actor in supporting role
cat2 = oscars_noms[oscars_noms.nominations.str.contains("Supporting")]
cat2['nominations'].unique()
# Out:
# array(['Best Actress in a Supporting Role',
#        'Best Actor in a Supporting Role',
#        'Best Performance by an Actor in a Supporting Role',
#        'Best Performance by an Actress in a Supporting Role'],
#       dtype=object)

# %%
#Best Actress in a Leading Role
cat3 = oscars_noms[oscars_noms.nominations.str.contains("Actress")]
cat3['nominations'].unique()
# Out:
# array(['Best Actress in a Leading Role',
#        'Best Actress in a Supporting Role',
#        'Best Performance by an Actress in a Leading Role',
#        'Best Performance by an Actress in a Supporting Role'],
#       dtype=object)

# %%
#Best Actress in a Supporting Role
cat4 = oscars_noms[oscars_noms.nominations.str.contains("Actress")]
cat4['nominations'].unique()
# Out:
# array(['Best Actress in a Leading Role',
#        'Best Actress in a Supporting Role',
#        'Best Performance by an Actress in a Leading Role',
#        'Best Performance by an Actress in a Supporting Role'],
#       dtype=object)

# %%
#Best Adapted Screenplay
cat5 = oscars_noms[oscars_noms.nominations.str.contains("Adapted")]
cat5['nominations'].unique()
# Out:
# array(['Best Writing, Best Screenplay - Adapted',
#        'Best Writing, Screenplay Adapted From Other Material',
#        'Best Writing, Adapted Screenplay', 'Best Adapted Screenplay'],
#       dtype=object)

# %%
#Best Animated Feature
cat6 = oscars_noms[oscars_noms.nominations.str.contains("Animated")]
cat6['nominations'].unique()
# Out:
# array(['Best Animated Feature Film of the Year'], dtype=object)

# %%
#Best Animated Short Film
cat7 = oscars_noms[oscars_noms.nominations.str.contains("Short")]
cat7['nominations'].unique()
# Out:
# array([], dtype=object)

# %%
#Best Art Direction
cat8 = oscars_noms[oscars_noms.nominations.str.contains("Art")]
cat8['nominations'].unique()
# Out:
# array(['Best Art Direction', 'Best Art Direction, Black-and-White',
#        'Best Art Direction-Interior Decoration, Black-and-White',
#        'Best Art Direction-Interior Decoration, Color',
#        'Best Art Direction-Set Decoration, Black-and-White',
#        'Best Art Direction-Set Decoration, Color',
#        'Best Art Direction-Set Decoration',
#        'Best Art Direction-Set Decoration, Black-and-White or Color',
#        'Best Achievement in Art Direction'], dtype=object)

# %%
#Best Cinematography
cat9 = oscars_noms[oscars_noms.nominations.str.contains("Cinematography")]
cat9['nominations'].unique()
# Out:
# array(['Best Cinematography', 'Best Cinematography, Color',
#        'Best Cinematography, Black-and-White',
#        'Best Achievement in Cinematography'], dtype=object)

# %%
#Best Costume Design
cat10 = oscars_noms[oscars_noms.nominations.str.contains("Costume")]
cat10['nominations'].unique()
# Out:
# array(['Best Costume Design, Black-and-White',
#        'Best Costume Design, Color',
#        'Best Costume Design, Black-and-White or Color',
#        'Best Costume Design', 'Best Achievement in Costume Design'],
#       dtype=object)

# %%
#Best Director
cat11 = oscars_noms[oscars_noms.nominations.str.contains("Director")]
cat11['nominations'].unique()
# Out:
# array(['Best Director, Dramatic Picture', 'Best Director'], dtype=object)

# %%
cat12 = oscars_noms[oscars_noms.nominations.str.contains("Documentary")]
cat12['nominations'].unique()
# Out:
# array([], dtype=object)

# %%
#Best Documentary Short Subject
cat13 = oscars_noms[oscars_noms.nominations.str.contains("Documentary")]
cat13['nominations'].unique()
# Out:
# array([], dtype=object)

# %%
#Best Film Editing
cat14 = oscars_noms[oscars_noms.nominations.str.contains("Editing")]
cat14['nominations'].unique()
# Out:
# array(['Best Film Editing', 'Best Effects, Sound Effects Editing',
#        'Best Sound Editing', 'Best Achievement in Film Editing',
#        'Best Achievement in Sound Editing'], dtype=object)

# %%
#Best Foreign Language Film
cat15 = oscars_noms[oscars_noms.nominations.str.contains("Language")]
cat15['nominations'].unique()
# Out:
# array(['Best Foreign Language Film',
#        'Best Foreign Language Film of the Year'], dtype=object)

# %%
#Best Makeup
cat16 = oscars_noms[oscars_noms.nominations.str.contains("Makeup")]
cat16['nominations'].unique()
# Out:
# array(['Best Makeup', 'Best Achievement in Makeup',
#        'Best Achievement in Makeup and Hairstyling'], dtype=object)

# %%
#Best Original Score
cat17 = oscars_noms[oscars_noms.nominations.str.contains("Score")]
cat17['nominations'].unique()
# Out:
# array(['Best Music, Score', 'Best Music, Original Score',
#        'Best Music, Score - Substantially Original',
#        'Best Music, Substantially Original Score',
#        'Best Music, Original Music Score',
#        'Best Music, Score of a Musical Picture (Original or Adaptation)',
#        'Best Music, Original Score for a Motion Picture (not a Musical)',
#        'Best Music, Scoring Adaptation and Original Song Score',
#        'Best Music, Original Dramatic Score',
#        'Best Music, Scoring Original Song Score and/or Adaptation',
#        'Best Music, Original Song Score and Its Adaptation or Best Adaptation Score',
#        'Best Music, Original Musical or Comedy Score',
#        'Best Achievement in Music Written for Motion Pictures, Original Score',
#        'Best Achievement in Music Written for Motion Pictures (Original Score)'],
#       dtype=object)

# %%
#Best Original Screenplay
cat18 = oscars_noms[oscars_noms.nominations.str.contains("Screenplay")]
cat18['nominations'].unique()
# Out:
# array(['Best Writing, Screenplay', 'Best Writing, Original Screenplay',
#        'Best Writing, Story and Screenplay',
#        'Best Writing, Best Screenplay - Adapted',
#        'Best Writing, Screenplay Based on Material from Another Medium',
#        'Best Writing, Story and Screenplay - Written Directly for the Screen',
#        'Best Writing, Story and Screenplay Based on Material Not Previously Published or Produced',
#        'Best Writing, Story and Screenplay Based on Factual Material or Material Not Previously Published or Produced',
#        'Best Writing, Screenplay Adapted From Other Material',
#        'Best Writing, Screenplay Written Directly for the Screen',
#        'Best Writing, Screenplay Based on Material Previously Produced or Published',
#        'Best Writing, Adapted Screenplay', 'Best Adapted Screenplay',
#        'Best Original Screenplay'], dtype=object)

# %%
#Best Original Song
cat19 = oscars_noms[oscars_noms.nominations.str.contains("Song")]
cat19['nominations'].unique()
# Out:
# array(['Best Music, Original Song',
#        'Best Music, Scoring Adaptation and Original Song Score',
#        'Best Music, Scoring Original Song Score and/or Adaptation',
#        'Best Music, Original Song Score and Its Adaptation or Best Adaptation Score',
#        'Best Achievement in Music Written for Motion Pictures, Original Song',
#        'Best Achievement in Music Written for Motion Pictures (Original Song)'],
#       dtype=object)

# %%
#Best Sound Editing
cat20 = oscars_noms[oscars_noms.nominations.str.contains("Editing")]
cat20['nominations'].unique()
# Out:
# array(['Best Film Editing', 'Best Effects, Sound Effects Editing',
#        'Best Sound Editing', 'Best Achievement in Film Editing',
#        'Best Achievement in Sound Editing'], dtype=object)

# %%
#Best Sound Mixing
cat21 = oscars_noms[oscars_noms.nominations.str.contains("Sound")]
cat21['nominations'].unique()
# Out:
# array(['Best Sound, Recording', 'Best Sound',
#        'Best Effects, Sound Effects',
#        'Best Effects, Sound Effects Editing', 'Best Sound Editing',
#        'Best Sound Mixing', 'Best Achievement in Sound Mixing',
#        'Best Achievement in Sound Editing'], dtype=object)

# %%
#Best Visual Effects
cat22 = oscars_noms[oscars_noms.nominations.str.contains("Visual")]
cat22['nominations'].unique()
# Out:
# array(['Best Effects, Special Visual Effects',
#        'Best Effects, Visual Effects', 'Best Visual Effects',
#        'Best Achievement in Visual Effects'], dtype=object)

# %%
#Live Action Short Film
cat23 = oscars_noms[oscars_noms.nominations.str.contains("Short")]
cat23['nominations'].unique()
# Out:
# array([], dtype=object)

# %%
oscars_noms['nominations'] = oscars_noms['nominations'].replace(
    {'Best Performance by an Actor in a Leading Role':'Best Actor in a Leading Role',#Best actor in leading role
    'Best Performance by an Actor in a Supporting Role':'Best Actor in a Supporting Role',#Best actor in supporting role
    'Best Performance by an Actress in a Leading Role':'Best Actress in a Leading Role', #'Best Actress in a Leading Role'
    'Best Performance by an Actress in a Supporting Role':'Best Actress in a Supporting Role', #Best Actress in a Supporting Role
    'Best Writing, Best Screenplay - Adapted':'Best Adapted Screenplay', #Best Adapted Screenplay
        'Best Writing, Screenplay Adapted From Other Material':'Best Adapted Screenplay',
        'Best Writing, Adapted Screenplay': 'Best Adapted Screenplay',
        'Best Writing, Adaptation':'Best Adapted Screenplay',
    'Best Art Direction, Black-and-White': 'Best Art Direction', #Best Art Direction
       'Best Art Direction-Interior Decoration, Black-and-White':'Best Art Direction',
        'Best Achievement in Production Design':'Best Art Direction',
       'Best Art Direction-Interior Decoration, Color': 'Best Art Direction',
       'Best Art Direction-Set Decoration, Black-and-White':'Best Art Direction',
       'Best Art Direction-Set Decoration, Color':'Best Art Direction',
       'Best Art Direction-Set Decoration':'Best Art Direction',
       'Best Art Direction-Set Decoration, Black-and-White or Color':'Best Art Direction',
       'Best Achievement in Art Direction':'Best Art Direction',
    'Best Cinematography, Color':'Best Cinematography', #Best Cinematography
       'Best Cinematography, Black-and-White':'Best Cinematography',
       'Best Achievement in Cinematography':'Best Cinematography',
    'Best Costume Design, Black-and-White':'Best Costume Design', #Best Costume Design
       'Best Costume Design, Color':'Best Costume Design',
       'Best Costume Design, Black-and-White or Color':'Best Costume Design',
       'Best Achievement in Costume Design':'Best Costume Design',
    'Best Director, Dramatic Picture':'Best Director',#Best Director
         'Best Achievement in Directing':'Best Director',
    'Best Sound Editing':'Best Film Editing',#Best Film Editing
       'Best Achievement in Film Editing':'Best Film Editing',
    'Best Foreign Language Film of the Year':'Best Foreign Language Film',#Best Foreign Language Film
        'Best International Feature Film':'Best Foreign Language Film',
    'Best Achievement in Makeup':'Best Makeup',#Best Makeup
       'Best Achievement in Makeup and Hairstyling':'Best Makeup',
    'Best Music, Score':'Best Original Score',#Best Original Score
        'Best Music, Original Score':'Best Original Score',
        'Best Music, Scoring':'Best Original Score',
        'Best Music, Scoring of a Dramatic Picture':'Best Original Score',
       'Best Music, Score - Substantially Original':'Best Original Score',
       'Best Music, Substantially Original Score':'Best Original Score',
       'Best Music, Original Music Score':'Best Original Score',
       'Best Music, Score of a Musical Picture (Original or Adaptation)':'Best Original Score',
       'Best Music, Original Score for a Motion Picture (not a Musical)':'Best Original Score',
       'Best Music, Scoring Adaptation and Original Song Score':'Best Original Score',
       'Best Music, Original Dramatic Score':'Best Original Score',
       'Best Music, Scoring Original Song Score and/or Adaptation':'Best Original Score',
       'Best Music, Original Song Score and Its Adaptation or Best Adaptation Score':'Best Original Score',
       'Best Music, Original Musical or Comedy Score':'Best Original Score',
       'Best Achievement in Music Written for Motion Pictures, Original Score':'Best Original Score',
       'Best Achievement in Music Written for Motion Pictures (Original Score)':'Best Original Score',
    'Best Writing, Screenplay':'Best Original Screenplay',#Best Original Screenplay
        'Best Writing, Original Screenplay':'Best Original Screenplay',
         'Best Writing, Achievement':'Best Original Screenplay',
       'Best Writing, Story and Screenplay':'Best Original Screenplay',
       'Best Writing, Story and Screenplay - Written Directly for the Screen':'Best Original Screenplay',
       'Best Writing, Screenplay Written Directly for the Screen':'Best Original Screenplay',
        'Best Writing, Screenplay Based on Material from Another Medium':'Best Original Screenplay',
       'Best Writing, Story and Screenplay Based on Material Not Previously Published or Produced':'Best Original Screenplay',
       'Best Writing, Story and Screenplay Based on Factual Material or Material Not Previously Published or Produced':'Best Original Screenplay',
       'Best Writing, Screenplay Based on Material Previously Produced or Published':'Best Original Screenplay',
        'Best Writing, Original Story':'Best Original Screenplay',
       'Best Writing, Motion Picture Story':'Best Original Screenplay',
     'Best Music, Original Song':'Best Original Song',#Best Original Song
       'Best Achievement in Music Written for Motion Pictures, Original Song':'Best Original Song',
       'Best Achievement in Music Written for Motion Pictures (Original Song)':'Best Original Song',
     'Best Effects, Sound Effects Editing':'Best Sound Editing', #Best Sound Editing
         'Best Achievement in Sound Editing': 'Best Sound Editing',
     'Best Sound, Recording':'Best Sound Mixing',#Best Sound Mixing
       'Best Effects, Sound Effects':'Best Sound Mixing',
       'Best Achievement in Sound Mixing':'Best Sound Mixing',
        'Best Sound':'Best Sound Mixing',
     'Best Effects, Special Visual Effects':'Best Visual Effects',#Best Visual Effects
       'Best Effects, Visual Effects':'Best Visual Effects',
       'Best Achievement in Visual Effects':'Best Visual Effects',
         'Best Effects, Special Effects':'Best Visual Effects'
    })

# %%
len(oscars_noms['nominations'].unique().tolist())
# Out:
# 19

# %%
allcat = oscars_noms[~oscars_noms['nominations'].isin(['Best Original Song',
'Best Sound Mixing',
'Best Visual Effects',
'Best Actor in a Leading Role',
'Best Actor in a Supporting Role',
'Best Actress in a Leading Role',
'Best Actress in a Supporting Role',
'Best Adapted Screenplay',
'Best Art Direction',
'Best Cinematography',
'Best Costume Design',
'Best Director',
'Best Foreign Language Film',
'Best Makeup',
'Best Original Score',
'Best Original Screenplay',
'Best Film Editing',
'Best Animated Feature Film of the Year',
'Best Sound Editing'])]
allcat['nominations'].unique().tolist() #Making sure there are no more unaccounted categories
# Out:
# []

# %%
oscars_noms['nominations'].unique().tolist() #19 cats
# Out:
# ['Best Actress in a Leading Role',
#  'Best Director',
#  'Best Adapted Screenplay',
#  'Best Art Direction',
#  'Best Actor in a Leading Role',
#  'Best Original Screenplay',
#  'Best Cinematography',
#  'Best Sound Mixing',
#  'Best Film Editing',
#  'Best Original Song',
#  'Best Original Score',
#  'Best Actress in a Supporting Role',
#  'Best Actor in a Supporting Role',
#  'Best Visual Effects',
#  'Best Costume Design',
#  'Best Foreign Language Film',
#  'Best Makeup',
#  'Best Sound Editing',
#  'Best Animated Feature Film of the Year']

# %% [markdown]
# ### Accounting for the combination of story and screenplay, big picture, and 4 other categories that were not mentioned in this dataset we have a total of 19 other categories
#
# #### Now we can begin to transpose the unquie nominations into its own column

# %%
for column in oscars_noms['nominations'].unique():
    oscars_noms[column] = (oscars_noms["nominations"] == column)#Im placing every nomination as its own column to help the data frame become normalized

# %%
len(oscars_noms.columns)
# Out:
# 32

# %%
oscars_noms.head()
# Out:
#    movie_number                Title  Date Viewership_Rating  IMDb Rating  \
# 3             2           7th Heaven  1927         Not Rated          7.6
# 4             2           7th Heaven  1927         Not Rated          7.6
# 5             2           7th Heaven  1927         Not Rated          7.6
# 6             2           7th Heaven  1927         Not Rated          7.6
# 9             4  The Broadway Melody  1929            Passed          5.6
#
#   Country of Origin         Production Company  \
# 3     United States   Frank Borzage Production
# 4     United States   Frank Borzage Production
# 5     United States   Frank Borzage Production
# 6     United States   Frank Borzage Production
# 9     United States  Metro-Goldwyn-Mayer (MGM)
#
#                       nominations Genre 1  Genre 2  Genre 3  Duration  \
# 3  Best Actress in a Leading Role   Drama  Romance  Romance    130.76
# 4                   Best Director   Drama  Romance  Romance    130.76
# 5         Best Adapted Screenplay   Drama  Romance  Romance    130.76
# 6              Best Art Direction   Drama  Romance  Romance    130.76
# 9  Best Actress in a Leading Role   Drama  Musical  Romance    100.00
#
#    adj_Budget  Best Actress in a Leading Role  Best Director  \
# 3   1300000.0                            True          False
# 4   1300000.0                           False           True
# 5   1300000.0                           False          False
# 6   1300000.0                           False          False
# 9    379000.0                            True          False
#
#    Best Adapted Screenplay  Best Art Direction  Best Actor in a Leading Role  \
# 3                    False               False                         False
# 4                    False               False                         False
# 5                     True               False                         False
# 6                    False                True                         False
# 9                    False               False                         False
#
#    Best Original Screenplay  Best Cinematography  Best Sound Mixing  \
# 3                     False                False              False
# 4                     False                False              False
# 5                     False                False              False
# 6                     False                False              False
# 9                     False                False              False
#
#    Best Film Editing  Best Original Song  Best Original Score  \
# 3              False               False                False
# 4              False               False                False
# 5              False               False                False
# 6              False               False                False
# 9              False               False                False
#
#    Best Actress in a Supporting Role  Best Actor in a Supporting Role  \
# 3                              False                            False
# 4                              False                            False
# 5                              False                            False
# 6                              False                            False
# 9                              False                            False
#
#    Best Visual Effects  Best Costume Design  Best Foreign Language Film  \
# 3                False                False                       False
# 4                False                False                       False
# 5                False                False                       False
# 6                False                False                       False
# 9                False                False                       False
#
#    Best Makeup  Best Sound Editing  Best Animated Feature Film of the Year
# 3        False               False                                   False
# 4        False               False                                   False
# 5        False               False                                   False
# 6        False               False                                   False
# 9        False               False                                   False

# %%
oscars_noms.info()# no more nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3092 entries, 3 to 3757
# Data columns (total 32 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   movie_number                            3092 non-null   int64
#  1   Title                                   3092 non-null   object
#  2   Date                                    3092 non-null   int64
#  3   Viewership_Rating                       3092 non-null   object
#  4   IMDb Rating                             3092 non-null   float64
#  5   Country of Origin                       3092 non-null   object
#  6   Production Company                      3092 non-null   object
#  7   nominations                             3092 non-null   object
#  8   Genre 1                                 3092 non-null   object
#  9   Genre 2                                 3092 non-null   object
#  10  Genre 3                                 3092 non-null   object
#  11  Duration                                3092 non-null   float64
#  12  adj_Budget                              3092 non-null   float64
#  13  Best Actress in a Leading Role          3092 non-null   bool
#  14  Best Director                           3092 non-null   bool
#  15  Best Adapted Screenplay                 3092 non-null   bool
#  16  Best Art Direction                      3092 non-null   bool
#  17  Best Actor in a Leading Role            3092 non-null   bool
#  18  Best Original Screenplay                3092 non-null   bool
#  19  Best Cinematography                     3092 non-null   bool
#  20  Best Sound Mixing                       3092 non-null   bool
#  21  Best Film Editing                       3092 non-null   bool
#  22  Best Original Song                      3092 non-null   bool
#  23  Best Original Score                     3092 non-null   bool
#  24  Best Actress in a Supporting Role       3092 non-null   bool
#  25  Best Actor in a Supporting Role         3092 non-null   bool
#  26  Best Visual Effects                     3092 non-null   bool
#  27  Best Costume Design                     3092 non-null   bool
#  28  Best Foreign Language Film              3092 non-null   bool
#  29  Best Makeup                             3092 non-null   bool
#  30  Best Sound Editing                      3092 non-null   bool
#  31  Best Animated Feature Film of the Year  3092 non-null   bool
# dtypes: bool(19), float64(3), int64(2), object(8)
# memory usage: 395.6+ KB

# %% [markdown]
# ## Despite all of that the dataset is still not normlized because there are still duplicates. Transposing only added new columns and did not remove the duplicates. However it did make it easier to consolidate the dataset

# %% [markdown]
# ### Consildate to make unqiue values

# %%
oscars_noms.groupby('movie_number').agg(lambda grp: grp.nlargest(1).max()).reset_index().head()
# Out:
# C:\Users\kylep\AppData\Local\Temp\ipykernel_22292\1724193417.py:1: FutureWarning: ['Title', 'Viewership_Rating', 'Country of Origin', 'Production Company', 'nominations', 'Genre 1', 'Genre 2', 'Genre 3'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   oscars_noms.groupby('movie_number').agg(lambda grp: grp.nlargest(1).max()).reset_index().head()
#    movie_number  Date  IMDb Rating  Duration  adj_Budget  \
# 0             2  1927         7.60    130.76  1300000.00
# 1             4  1929         5.60    100.00   379000.00
# 2             5  1928         5.50     95.00  1000000.00
# 3             6  1928         7.62    130.76  1000000.00
# 4             8  1929         5.70     91.00   559666.67
#
#    Best Actress in a Leading Role  Best Director  Best Adapted Screenplay  \
# 0                            True           True                     True
# 1                            True           True                    False
# 2                           False           True                    False
# 3                           False           True                    False
# 4                           False          False                    False
#
#    Best Art Direction  Best Actor in a Leading Role  Best Original Screenplay  \
# 0                True                         False                     False
# 1               False                         False                     False
# 2               False                          True                      True
# 3                True                          True                      True
# 4                True                          True                     False
#
#    Best Cinematography  Best Sound Mixing  Best Film Editing  \
# 0                False              False              False
# 1                False              False              False
# 2                 True              False              False
# 3                False              False              False
# 4                False              False              False
#
#    Best Original Song  Best Original Score  Best Actress in a Supporting Role  \
# 0               False                False                              False
# 1               False                False                              False
# 2               False                False                              False
# 3               False                False                              False
# 4               False                False                              False
#
#    Best Actor in a Supporting Role  Best Visual Effects  Best Costume Design  \
# 0                            False                False                False
# 1                            False                False                False
# 2                            False                False                False
# 3                            False                False                False
# 4                            False                False                False
#
#    Best Foreign Language Film  Best Makeup  Best Sound Editing  \
# 0                       False        False               False
# 1                       False        False               False
# 2                       False        False               False
# 3                       False        False               False
# 4                       False        False               False
#
#    Best Animated Feature Film of the Year
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False

# %% [markdown]
# ### You might be wondering as to why I didnt just group by the Title. That is becaue there were about 6 movies that have the same name. In other words remakes were considered there own movie. Here I had choice on making the combination of title and date the unique identifer or just make movie number be the identifer.

# %% [markdown]
# ## Done with Cleaning. Time to do some things to prep the data for a predticion model.
# ### Since we know that winning the oscars is a classifer our data will need one as well. That way the model knows what to look for.

# %%
# First thing I need is a list of every past winner
winners = pd.read_csv(r"C:\Users\kylep\Documents\Work things\Projects\Python\Oscars\EveryBestPictureWinner.csv")

# %%
winners.head() # We only need the titles
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1685170429-1  https://www.imdb.com/search/title/?count=100&g...
# 1      1685170429-2  https://www.imdb.com/search/title/?count=100&g...
# 2      1685170429-3  https://www.imdb.com/search/title/?count=100&g...
# 3      1685170429-4  https://www.imdb.com/search/title/?count=100&g...
# 4      1685170429-5  https://www.imdb.com/search/title/?count=100&g...
#
#                                Title  Date  Unnamed: 4
# 0  Everything Everywhere All at Once  2022        True
# 1                               CODA  2021        True
# 2                          Nomadland  2020        True
# 3                           Parasite  2019        True
# 4                         Green Book  2018        True

# %%
winners = winners.rename(columns={'Unnamed: 4': 'Winner'})

# %%
winners.drop(['web-scraper-order', 'web-scraper-start-url'], axis=1, inplace=True)

# %%
winners['Title'].value_counts().sum()
# Out:
# 96

# %%
winners.head()
# Out:
#                                Title  Date  Winner
# 0  Everything Everywhere All at Once  2022    True
# 1                               CODA  2021    True
# 2                          Nomadland  2020    True
# 3                           Parasite  2019    True
# 4                         Green Book  2018    True

# %%
oscars_noms.head()
# Out:
#    movie_number                Title  Date Viewership_Rating  IMDb Rating  \
# 3             2           7th Heaven  1927         Not Rated          7.6
# 4             2           7th Heaven  1927         Not Rated          7.6
# 5             2           7th Heaven  1927         Not Rated          7.6
# 6             2           7th Heaven  1927         Not Rated          7.6
# 9             4  The Broadway Melody  1929            Passed          5.6
#
#   Country of Origin         Production Company  \
# 3     United States   Frank Borzage Production
# 4     United States   Frank Borzage Production
# 5     United States   Frank Borzage Production
# 6     United States   Frank Borzage Production
# 9     United States  Metro-Goldwyn-Mayer (MGM)
#
#                       nominations Genre 1  Genre 2  Genre 3  Duration  \
# 3  Best Actress in a Leading Role   Drama  Romance  Romance    130.76
# 4                   Best Director   Drama  Romance  Romance    130.76
# 5         Best Adapted Screenplay   Drama  Romance  Romance    130.76
# 6              Best Art Direction   Drama  Romance  Romance    130.76
# 9  Best Actress in a Leading Role   Drama  Musical  Romance    100.00
#
#    adj_Budget  Best Actress in a Leading Role  Best Director  \
# 3   1300000.0                            True          False
# 4   1300000.0                           False           True
# 5   1300000.0                           False          False
# 6   1300000.0                           False          False
# 9    379000.0                            True          False
#
#    Best Adapted Screenplay  Best Art Direction  Best Actor in a Leading Role  \
# 3                    False               False                         False
# 4                    False               False                         False
# 5                     True               False                         False
# 6                    False                True                         False
# 9                    False               False                         False
#
#    Best Original Screenplay  Best Cinematography  Best Sound Mixing  \
# 3                     False                False              False
# 4                     False                False              False
# 5                     False                False              False
# 6                     False                False              False
# 9                     False                False              False
#
#    Best Film Editing  Best Original Song  Best Original Score  \
# 3              False               False                False
# 4              False               False                False
# 5              False               False                False
# 6              False               False                False
# 9              False               False                False
#
#    Best Actress in a Supporting Role  Best Actor in a Supporting Role  \
# 3                              False                            False
# 4                              False                            False
# 5                              False                            False
# 6                              False                            False
# 9                              False                            False
#
#    Best Visual Effects  Best Costume Design  Best Foreign Language Film  \
# 3                False                False                       False
# 4                False                False                       False
# 5                False                False                       False
# 6                False                False                       False
# 9                False                False                       False
#
#    Best Makeup  Best Sound Editing  Best Animated Feature Film of the Year
# 3        False               False                                   False
# 4        False               False                                   False
# 5        False               False                                   False
# 6        False               False                                   False
# 9        False               False                                   False

# %%
df_osc = pd.merge(oscars_noms,winners,how="left",on=['Title','Date']) #combing the two dataframes

# %%
df_osc.head()
# Out:
#    movie_number                Title  Date Viewership_Rating  IMDb Rating  \
# 0             2           7th Heaven  1927         Not Rated          7.6
# 1             2           7th Heaven  1927         Not Rated          7.6
# 2             2           7th Heaven  1927         Not Rated          7.6
# 3             2           7th Heaven  1927         Not Rated          7.6
# 4             4  The Broadway Melody  1929            Passed          5.6
#
#   Country of Origin         Production Company  \
# 0     United States   Frank Borzage Production
# 1     United States   Frank Borzage Production
# 2     United States   Frank Borzage Production
# 3     United States   Frank Borzage Production
# 4     United States  Metro-Goldwyn-Mayer (MGM)
#
#                       nominations Genre 1  Genre 2  Genre 3  Duration  \
# 0  Best Actress in a Leading Role   Drama  Romance  Romance    130.76
# 1                   Best Director   Drama  Romance  Romance    130.76
# 2         Best Adapted Screenplay   Drama  Romance  Romance    130.76
# 3              Best Art Direction   Drama  Romance  Romance    130.76
# 4  Best Actress in a Leading Role   Drama  Musical  Romance    100.00
#
#    adj_Budget  Best Actress in a Leading Role  Best Director  \
# 0   1300000.0                            True          False
# 1   1300000.0                           False           True
# 2   1300000.0                           False          False
# 3   1300000.0                           False          False
# 4    379000.0                            True          False
#
#    Best Adapted Screenplay  Best Art Direction  Best Actor in a Leading Role  \
# 0                    False               False                         False
# 1                    False               False                         False
# 2                     True               False                         False
# 3                    False                True                         False
# 4                    False               False                         False
#
#    Best Original Screenplay  Best Cinematography  Best Sound Mixing  \
# 0                     False                False              False
# 1                     False                False              False
# 2                     False                False              False
# 3                     False                False              False
# 4                     False                False              False
#
#    Best Film Editing  Best Original Song  Best Original Score  \
# 0              False               False                False
# 1              False               False                False
# 2              False               False                False
# 3              False               False                False
# 4              False               False                False
#
#    Best Actress in a Supporting Role  Best Actor in a Supporting Role  \
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
#
#    Best Visual Effects  Best Costume Design  Best Foreign Language Film  \
# 0                False                False                       False
# 1                False                False                       False
# 2                False                False                       False
# 3                False                False                       False
# 4                False                False                       False
#
#    Best Makeup  Best Sound Editing  Best Animated Feature Film of the Year  \
# 0        False               False                                   False
# 1        False               False                                   False
# 2        False               False                                   False
# 3        False               False                                   False
# 4        False               False                                   False
#
#   Winner
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4   True

# %%
df_osc['Winner'] = df_osc['Winner'].fillna(False) #Filling all instance of naan with False

# %%
df_osc['Winner'].dtypes #Making sure the winner feature is a true or false category
# Out:
# dtype('bool')

# %%
df = df_osc.groupby('movie_number').agg(lambda grp: grp.nlargest(1).max()).reset_index() #Normalizing the combined dataframe
# Out:
# C:\Users\kylep\AppData\Local\Temp\ipykernel_22292\1046796167.py:1: FutureWarning: ['Title', 'Viewership_Rating', 'Country of Origin', 'Production Company', 'nominations', 'Genre 1', 'Genre 2', 'Genre 3'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df = df_osc.groupby('movie_number').agg(lambda grp: grp.nlargest(1).max()).reset_index() #Normalizing the combined dataframe

# %%
df.head()
# Out:
#    movie_number  Date  IMDb Rating  Duration  adj_Budget  \
# 0             2  1927         7.60    130.76  1300000.00
# 1             4  1929         5.60    100.00   379000.00
# 2             5  1928         5.50     95.00  1000000.00
# 3             6  1928         7.62    130.76  1000000.00
# 4             8  1929         5.70     91.00   559666.67
#
#    Best Actress in a Leading Role  Best Director  Best Adapted Screenplay  \
# 0                            True           True                     True
# 1                            True           True                    False
# 2                           False           True                    False
# 3                           False           True                    False
# 4                           False          False                    False
#
#    Best Art Direction  Best Actor in a Leading Role  Best Original Screenplay  \
# 0                True                         False                     False
# 1               False                         False                     False
# 2               False                          True                      True
# 3                True                          True                      True
# 4                True                          True                     False
#
#    Best Cinematography  Best Sound Mixing  Best Film Editing  \
# 0                False              False              False
# 1                False              False              False
# 2                 True              False              False
# 3                False              False              False
# 4                False              False              False
#
#    Best Original Song  Best Original Score  Best Actress in a Supporting Role  \
# 0               False                False                              False
# 1               False                False                              False
# 2               False                False                              False
# 3               False                False                              False
# 4               False                False                              False
#
#    Best Actor in a Supporting Role  Best Visual Effects  Best Costume Design  \
# 0                            False                False                False
# 1                            False                False                False
# 2                            False                False                False
# 3                            False                False                False
# 4                            False                False                False
#
#    Best Foreign Language Film  Best Makeup  Best Sound Editing  \
# 0                       False        False               False
# 1                       False        False               False
# 2                       False        False               False
# 3                       False        False               False
# 4                       False        False               False
#
#    Best Animated Feature Film of the Year  Winner
# 0                                   False   False
# 1                                   False    True
# 2                                   False   False
# 3                                   False   False
# 4                                   False   False

# %%
df['Winner'].value_counts()#There should be 96 winners
# Out:
# False    480
# True      93
# Name: Winner, dtype: int64

# %%
df_osc.groupby('Title').agg({'Winner':'max'}).head()#Checking which movies are not listed as true
#Note:Made smaller for publish
# Out:
#                   Winner
# Title
# 12 Angry Men       False
# 12 Years a Slave    True
# 127 Hours          False
# 1917               False
# 42nd Street        False

# %% [markdown]
# ## Checking which Movies were not selected as winners when they should have

# %%
array = oscars_noms['Title'].unique() #Making an array with all movie titles

# %%
winners[~winners.Title.isin(array)] #Filtering out all movies that should be in the winners dataframe that arent
# Out:
#           Title  Date  Winner
# 90  Grand Hotel  1932    True
# 94        Wings  1927    True
# 95      Sunrise  1927    True

# %% [markdown]
# ### Exploring the three titles

# %%
df_osc[df_osc['Title'] == 'Sunrise']
# Out:
# Empty DataFrame
# Columns: [movie_number, Title, Date, Viewership_Rating, IMDb Rating, Country of Origin, Production Company, nominations, Genre 1, Genre 2, Genre 3, Duration, adj_Budget, Best Actress in a Leading Role, Best Director, Best Adapted Screenplay, Best Art Direction, Best Actor in a Leading Role, Best Original Screenplay, Best Cinematography, Best Sound Mixing, Best Film Editing, Best Original Song, Best Original Score, Best Actress in a Supporting Role, Best Actor in a Supporting Role, Best Visual Effects, Best Costume Design, Best Foreign Language Film, Best Makeup, Best Sound Editing, Best Animated Feature Film of the Year, Winner]
# Index: []

# %% [markdown]
# #### After some research it seems this movie had some contervesy in terms of its title as best picture. One of them being that the award was later taken away. This is the reason as to why my orginal dataframe that contained all movies nominated did not match the winners dataframe. You can read more about it in here: https://www.slashfilm.com/1171357/sunrise-is-the-only-best-picture-oscar-winner-the-academy-doesnt-recognize/

# %%
df_osc[df_osc['Title'] == 'Grand Hotel']
# Out:
# Empty DataFrame
# Columns: [movie_number, Title, Date, Viewership_Rating, IMDb Rating, Country of Origin, Production Company, nominations, Genre 1, Genre 2, Genre 3, Duration, adj_Budget, Best Actress in a Leading Role, Best Director, Best Adapted Screenplay, Best Art Direction, Best Actor in a Leading Role, Best Original Screenplay, Best Cinematography, Best Sound Mixing, Best Film Editing, Best Original Song, Best Original Score, Best Actress in a Supporting Role, Best Actor in a Supporting Role, Best Visual Effects, Best Costume Design, Best Foreign Language Film, Best Makeup, Best Sound Editing, Best Animated Feature Film of the Year, Winner]
# Index: []

# %% [markdown]
# #### This movie is the only movie ever to not be nominated for any other category and still win best picture. Thus when I consolidated my data frame it was left out

# %% [markdown]
# #### Considering these two movies were somewhat of anonmly I will preceded without them

# %%
df_osc[df_osc['Title'] == 'Wings']
# Out:
# Empty DataFrame
# Columns: [movie_number, Title, Date, Viewership_Rating, IMDb Rating, Country of Origin, Production Company, nominations, Genre 1, Genre 2, Genre 3, Duration, adj_Budget, Best Actress in a Leading Role, Best Director, Best Adapted Screenplay, Best Art Direction, Best Actor in a Leading Role, Best Original Screenplay, Best Cinematography, Best Sound Mixing, Best Film Editing, Best Original Song, Best Original Score, Best Actress in a Supporting Role, Best Actor in a Supporting Role, Best Visual Effects, Best Costume Design, Best Foreign Language Film, Best Makeup, Best Sound Editing, Best Animated Feature Film of the Year, Winner]
# Index: []

# %% [markdown]
# #### The reason why this movie no longer exsits in my dataframe is that the nominations that it earned was for best picture and Best Effects, Engineering Effects. Both of which were removed during the nomination portion of cleaning.

# %% [markdown]
# ### Since only three movies were not accounted for and they were some what of outliers I will continue without them

# %% [markdown]
# # =============================================================

# %% [markdown]
# ## Although we already know who the 2023 winner is we are still in the middle of the 2024 running and thus dont know which movies will be nominated for the 2024 oscars. Thus we will remove the 2023 nominees and try to predict them.

# %% [markdown]
# ### The first thing we have to do is remove those movies from the main data and categorize it as our unseen data set

# %%
df.head() #Norm dataset
# Out:
#    movie_number  Date  IMDb Rating  Duration  adj_Budget  \
# 0             2  1927         7.60    130.76  1300000.00
# 1             4  1929         5.60    100.00   379000.00
# 2             5  1928         5.50     95.00  1000000.00
# 3             6  1928         7.62    130.76  1000000.00
# 4             8  1929         5.70     91.00   559666.67
#
#    Best Actress in a Leading Role  Best Director  Best Adapted Screenplay  \
# 0                            True           True                     True
# 1                            True           True                    False
# 2                           False           True                    False
# 3                           False           True                    False
# 4                           False          False                    False
#
#    Best Art Direction  Best Actor in a Leading Role  Best Original Screenplay  \
# 0                True                         False                     False
# 1               False                         False                     False
# 2               False                          True                      True
# 3                True                          True                      True
# 4                True                          True                     False
#
#    Best Cinematography  Best Sound Mixing  Best Film Editing  \
# 0                False              False              False
# 1                False              False              False
# 2                 True              False              False
# 3                False              False              False
# 4                False              False              False
#
#    Best Original Song  Best Original Score  Best Actress in a Supporting Role  \
# 0               False                False                              False
# 1               False                False                              False
# 2               False                False                              False
# 3               False                False                              False
# 4               False                False                              False
#
#    Best Actor in a Supporting Role  Best Visual Effects  Best Costume Design  \
# 0                            False                False                False
# 1                            False                False                False
# 2                            False                False                False
# 3                            False                False                False
# 4                            False                False                False
#
#    Best Foreign Language Film  Best Makeup  Best Sound Editing  \
# 0                       False        False               False
# 1                       False        False               False
# 2                       False        False               False
# 3                       False        False               False
# 4                       False        False               False
#
#    Best Animated Feature Film of the Year  Winner
# 0                                   False   False
# 1                                   False    True
# 2                                   False   False
# 3                                   False   False
# 4                                   False   False

# %%
df_osc.head() #Will first work on on non norm dataset
# Out:
#    movie_number                Title  Date Viewership_Rating  IMDb Rating  \
# 0             2           7th Heaven  1927         Not Rated          7.6
# 1             2           7th Heaven  1927         Not Rated          7.6
# 2             2           7th Heaven  1927         Not Rated          7.6
# 3             2           7th Heaven  1927         Not Rated          7.6
# 4             4  The Broadway Melody  1929            Passed          5.6
#
#   Country of Origin         Production Company  \
# 0     United States   Frank Borzage Production
# 1     United States   Frank Borzage Production
# 2     United States   Frank Borzage Production
# 3     United States   Frank Borzage Production
# 4     United States  Metro-Goldwyn-Mayer (MGM)
#
#                       nominations Genre 1  Genre 2  Genre 3  Duration  \
# 0  Best Actress in a Leading Role   Drama  Romance  Romance    130.76
# 1                   Best Director   Drama  Romance  Romance    130.76
# 2         Best Adapted Screenplay   Drama  Romance  Romance    130.76
# 3              Best Art Direction   Drama  Romance  Romance    130.76
# 4  Best Actress in a Leading Role   Drama  Musical  Romance    100.00
#
#    adj_Budget  Best Actress in a Leading Role  Best Director  \
# 0   1300000.0                            True          False
# 1   1300000.0                           False           True
# 2   1300000.0                           False          False
# 3   1300000.0                           False          False
# 4    379000.0                            True          False
#
#    Best Adapted Screenplay  Best Art Direction  Best Actor in a Leading Role  \
# 0                    False               False                         False
# 1                    False               False                         False
# 2                     True               False                         False
# 3                    False                True                         False
# 4                    False               False                         False
#
#    Best Original Screenplay  Best Cinematography  Best Sound Mixing  \
# 0                     False                False              False
# 1                     False                False              False
# 2                     False                False              False
# 3                     False                False              False
# 4                     False                False              False
#
#    Best Film Editing  Best Original Song  Best Original Score  \
# 0              False               False                False
# 1              False               False                False
# 2              False               False                False
# 3              False               False                False
# 4              False               False                False
#
#    Best Actress in a Supporting Role  Best Actor in a Supporting Role  \
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
#
#    Best Visual Effects  Best Costume Design  Best Foreign Language Film  \
# 0                False                False                       False
# 1                False                False                       False
# 2                False                False                       False
# 3                False                False                       False
# 4                False                False                       False
#
#    Best Makeup  Best Sound Editing  Best Animated Feature Film of the Year  \
# 0        False               False                                   False
# 1        False               False                                   False
# 2        False               False                                   False
# 3        False               False                                   False
# 4        False               False                                   False
#
#    Winner
# 0   False
# 1   False
# 2   False
# 3   False
# 4    True

# %% [markdown]
# ### Since we know that the non normalized dataframe(df_osc) is only non normalized becuse of the nomination columns we will convert the dataframe with the remaining features

# %%
df_osc = df_osc[['movie_number', 'Title','Viewership_Rating','Country of Origin',
                'Production Company','Genre 1','Genre 2','Genre 3']]

# %%
df_osc.head()
# Out:
#    movie_number                Title Viewership_Rating Country of Origin  \
# 0             2           7th Heaven         Not Rated     United States
# 1             2           7th Heaven         Not Rated     United States
# 2             2           7th Heaven         Not Rated     United States
# 3             2           7th Heaven         Not Rated     United States
# 4             4  The Broadway Melody            Passed     United States
#
#           Production Company Genre 1  Genre 2  Genre 3
# 0   Frank Borzage Production   Drama  Romance  Romance
# 1   Frank Borzage Production   Drama  Romance  Romance
# 2   Frank Borzage Production   Drama  Romance  Romance
# 3   Frank Borzage Production   Drama  Romance  Romance
# 4  Metro-Goldwyn-Mayer (MGM)   Drama  Musical  Romance

# %%
df_osc['movie_number'].nunique()
# Out:
# 573

# %%
df_osc.drop_duplicates(keep='first', inplace=True) #Normalizing the dataframe

# %%
df_osc.head()
# Out:
#     movie_number                Title Viewership_Rating Country of Origin  \
# 0              2           7th Heaven         Not Rated     United States
# 4              4  The Broadway Melody            Passed     United States
# 6              5       In Old Arizona            Passed     United States
# 10             6          The Patriot         Not Rated     United States
# 14             8                Alibi            Passed     United States
#
#            Production Company Genre 1  Genre 2   Genre 3
# 0    Frank Borzage Production   Drama  Romance   Romance
# 4   Metro-Goldwyn-Mayer (MGM)   Drama  Musical   Romance
# 6        Fox Film Corporation   Drama  Western   Western
# 10         Paramount Pictures   Drama  History  Thriller
# 14        Feature Productions  Action    Crime   Romance

# %%
oscars = pd.merge(df,df_osc,how="left",on=['movie_number']) #merging both dataframes that are now normalized

# %%
oscars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 573 entries, 0 to 572
# Data columns (total 32 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   movie_number                            573 non-null    int64
#  1   Date                                    573 non-null    int64
#  2   IMDb Rating                             573 non-null    float64
#  3   Duration                                573 non-null    float64
#  4   adj_Budget                              573 non-null    float64
#  5   Best Actress in a Leading Role          573 non-null    bool
#  6   Best Director                           573 non-null    bool
#  7   Best Adapted Screenplay                 573 non-null    bool
#  8   Best Art Direction                      573 non-null    bool
#  9   Best Actor in a Leading Role            573 non-null    bool
#  10  Best Original Screenplay                573 non-null    bool
#  11  Best Cinematography                     573 non-null    bool
#  12  Best Sound Mixing                       573 non-null    bool
#  13  Best Film Editing                       573 non-null    bool
#  14  Best Original Song                      573 non-null    bool
#  15  Best Original Score                     573 non-null    bool
#  16  Best Actress in a Supporting Role       573 non-null    bool
#  17  Best Actor in a Supporting Role         573 non-null    bool
#  18  Best Visual Effects                     573 non-null    bool
#  19  Best Costume Design                     573 non-null    bool
#  20  Best Foreign Language Film              573 non-null    bool
#  21  Best Makeup                             573 non-null    bool
#  22  Best Sound Editing                      573 non-null    bool
#  23  Best Animated Feature Film of the Year  573 non-null    bool
#  24  Winner                                  573 non-null    bool
#  25  Title                                   573 non-null    object
#  26  Viewership_Rating                       573 non-null    object
#  27  Country of Origin                       573 non-null    object
#  28  Production Company                      573 non-null    object
#  29  Genre 1                                 573 non-null    object
#  30  Genre 2                                 573 non-null    object
#  31  Genre 3                                 573 non-null    object
# dtypes: bool(20), float64(3), int64(2), object(7)
# memory usage: 69.4+ KB

# %%
osc_2023 = oscars[oscars['Date'] == 2022] #Filtering the movies that were nominated for the 2023 best picture award

# %%
osc_2023.drop('Winner', axis=1) 
#Since were are pretending that we still dont who won the 2023 best picture award we need to remove the winner cat
# Out:
#      movie_number  Date  IMDb Rating  Duration    adj_Budget  \
# 563           582  2022          7.8     139.0  1.430000e+07
# 564           583  2022          7.8     148.0  8.420682e+07
# 565           584  2022          7.7     192.0  3.500000e+08
# 566           585  2022          7.3     159.0  8.500000e+07
# 567           586  2022          7.7     114.0  8.420682e+07
# 568           587  2022          7.6     151.0  4.000000e+07
# 569           588  2022          8.3     130.0  1.700000e+08
# 570           589  2022          7.3     147.0  1.070000e+07
# 571           590  2022          7.5     158.0  2.500000e+07
# 572           591  2022          6.9     104.0  8.420682e+07
#
#      Best Actress in a Leading Role  Best Director  Best Adapted Screenplay  \
# 563                            True           True                    False
# 564                           False          False                     True
# 565                           False          False                    False
# 566                           False          False                    False
# 567                           False           True                    False
# 568                            True           True                    False
# 569                           False          False                     True
# 570                           False           True                    False
# 571                            True           True                    False
# 572                           False          False                     True
#
#      Best Art Direction  Best Actor in a Leading Role  \
# 563               False                         False
# 564                True                         False
# 565                True                         False
# 566                True                          True
# 567               False                          True
# 568                True                         False
# 569               False                         False
# 570               False                         False
# 571               False                         False
# 572               False                         False
#
#      Best Original Screenplay  Best Cinematography  Best Sound Mixing  \
# 563                      True                False              False
# 564                     False                 True               True
# 565                     False                False               True
# 566                     False                 True               True
# 567                      True                False              False
# 568                      True                False              False
# 569                     False                False               True
# 570                      True                False              False
# 571                      True                 True              False
# 572                     False                False              False
#
#      Best Film Editing  Best Original Song  Best Original Score  \
# 563               True                True                 True
# 564              False               False                 True
# 565              False               False                False
# 566               True               False                False
# 567               True               False                 True
# 568              False               False                 True
# 569               True                True                False
# 570              False               False                False
# 571               True               False                False
# 572              False               False                False
#
#      Best Actress in a Supporting Role  Best Actor in a Supporting Role  \
# 563                               True                             True
# 564                              False                            False
# 565                              False                            False
# 566                              False                            False
# 567                               True                             True
# 568                              False                             True
# 569                              False                            False
# 570                              False                            False
# 571                              False                            False
# 572                              False                            False
#
#      Best Visual Effects  Best Costume Design  Best Foreign Language Film  \
# 563                False                 True                       False
# 564                 True                False                        True
# 565                 True                False                       False
# 566                False                 True                       False
# 567                False                False                       False
# 568                False                False                       False
# 569                 True                False                       False
# 570                False                False                       False
# 571                False                False                       False
# 572                False                False                       False
#
#      Best Makeup  Best Sound Editing  Best Animated Feature Film of the Year  \
# 563        False               False                                   False
# 564         True               False                                   False
# 565        False               False                                   False
# 566         True               False                                   False
# 567        False               False                                   False
# 568        False               False                                   False
# 569        False               False                                   False
# 570        False               False                                   False
# 571        False               False                                   False
# 572        False               False                                   False
#
#                                  Title Viewership_Rating Country of Origin  \
# 563  Everything Everywhere All at Once                 R     United States
# 564     All Quiet on the Western Front                 R           Germany
# 565           Avatar: The Way of Water             PG-13     United States
# 566                              Elvis             PG-13     United States
# 567          The Banshees of Inisherin                 R    United Kingdom
# 568                      The Fabelmans             PG-13     United States
# 569                  Top Gun: Maverick             PG-13     United States
# 570                Triangle of Sadness                 R     United States
# 571                                Tár                 R     United States
# 572                      Women Talking             PG-13     United States
#
#                                     Production Company    Genre 1    Genre 2  \
# 563                                   A24IAC FilmsAGBO     Action  Adventure
# 564  Amusement Park FilmsGunpowder FilmsSliding Dow...     Action      Drama
# 565  20th Century StudiosTSG EntertainmentLightstor...     Action  Adventure
# 566    Warner Bros.Bazmark FilmsRoadshow Entertainment  Biography      Drama
# 567        Searchlight PicturesFilm4Blueprint Pictures     Comedy      Drama
# 568  Amblin EntertainmentAmblin PartnersReliance En...      Drama      Drama
# 569  Paramount PicturesSkydance MediaJerry Bruckhei...     Action      Drama
# 570  Imperative EntertainmentPlattform ProduktionFi...     Comedy      Drama
# 571  Focus FeaturesStandard Film CompanyEMJAG Produ...      Drama      Music
# 572           Hear/Say ProductionsPlan B Entertainment      Drama      Drama
#
#      Genre 3
# 563   Comedy
# 564      War
# 565  Fantasy
# 566    Music
# 567    Drama
# 568    Drama
# 569    Drama
# 570    Drama
# 571    Music
# 572    Drama

# %%
movies = oscars[oscars['Date'] != 2022] #Showing off the dataset I will be working in the machine learning part of this project
movies.head()
# Out:
#    movie_number  Date  IMDb Rating  Duration  adj_Budget  \
# 0             2  1927         7.60    130.76  1300000.00
# 1             4  1929         5.60    100.00   379000.00
# 2             5  1928         5.50     95.00  1000000.00
# 3             6  1928         7.62    130.76  1000000.00
# 4             8  1929         5.70     91.00   559666.67
#
#    Best Actress in a Leading Role  Best Director  Best Adapted Screenplay  \
# 0                            True           True                     True
# 1                            True           True                    False
# 2                           False           True                    False
# 3                           False           True                    False
# 4                           False          False                    False
#
#    Best Art Direction  Best Actor in a Leading Role  Best Original Screenplay  \
# 0                True                         False                     False
# 1               False                         False                     False
# 2               False                          True                      True
# 3                True                          True                      True
# 4                True                          True                     False
#
#    Best Cinematography  Best Sound Mixing  Best Film Editing  \
# 0                False              False              False
# 1                False              False              False
# 2                 True              False              False
# 3                False              False              False
# 4                False              False              False
#
#    Best Original Song  Best Original Score  Best Actress in a Supporting Role  \
# 0               False                False                              False
# 1               False                False                              False
# 2               False                False                              False
# 3               False                False                              False
# 4               False                False                              False
#
#    Best Actor in a Supporting Role  Best Visual Effects  Best Costume Design  \
# 0                            False                False                False
# 1                            False                False                False
# 2                            False                False                False
# 3                            False                False                False
# 4                            False                False                False
#
#    Best Foreign Language Film  Best Makeup  Best Sound Editing  \
# 0                       False        False               False
# 1                       False        False               False
# 2                       False        False               False
# 3                       False        False               False
# 4                       False        False               False
#
#    Best Animated Feature Film of the Year  Winner                Title  \
# 0                                   False   False           7th Heaven
# 1                                   False    True  The Broadway Melody
# 2                                   False   False       In Old Arizona
# 3                                   False   False          The Patriot
# 4                                   False   False                Alibi
#
#   Viewership_Rating Country of Origin         Production Company Genre 1  \
# 0         Not Rated     United States   Frank Borzage Production   Drama
# 1            Passed     United States  Metro-Goldwyn-Mayer (MGM)   Drama
# 2            Passed     United States       Fox Film Corporation   Drama
# 3         Not Rated     United States         Paramount Pictures   Drama
# 4            Passed     United States        Feature Productions  Action
#
#    Genre 2   Genre 3
# 0  Romance   Romance
# 1  Musical   Romance
# 2  Western   Western
# 3  History  Thriller
# 4    Crime   Romance

# %% [markdown]
# # =============================================================

# %% [markdown]
# # Creating two CSV files. One will be my main dataframe that I will train my model on(movies.csv) and the other will be my unseen dataframe(osc_2023.csv)

# %%
#osc_2023.to_csv('osc_2023_data.csv', encoding='utf-8')

# %%
#movies.to_csv('movie_data.csv', encoding='utf-8')
